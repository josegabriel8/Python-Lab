# %% [markdown]
# # **Exercise**

# %% [markdown]
# Build a dataframe from the .json data in `trips.json` file in the folder
#
# ```
# /content/drive/MyDrive/Colab Notebooks/data
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Make sure that the data types in the dataframe are correct and answer the following questions:
#
# * What are the different `usertype` values?
# * What is the time span for the data?
# * How many different days?
# * Compute a few stats for tripduration

# %% [markdown]
# -The membership of the bike user
# -minutes

# %%
import pandas as pd

k = pd.read_json('/content/drive/MyDrive/Colab Notebooks/data/trips.json', lines=True)
k.describe()

# %%
import pandas as pd

k = pd.read_json('/content/drive/MyDrive/Colab Notebooks/data/trips.json', lines=True)
k

# %% [markdown]
# # **Exercise**
#
# * Define your own metrics to detect outliers for the tripduration
# * Filter the trip duration outliers of the dataset

# %%
mean = k['tripduration'].mean()
std_dev = k['tripduration'].std()

k['out'] = k['tripduration'].apply(lambda x: 1 if x > mean + 2 * std_dev or x < mean - 2 * std_dev else 0)


k2 = k.query('out==0')

# %% [markdown]
# # **Exercise**
#
# * Add a new column with the age of the users.

# %%
k['birth year'].

# %% [markdown]
# # **Exercise**
#
# * Study the dates for the observations in the dataset.
# * Select an appropriate data subsect to allow a fair comparison between the different days.

# %% [markdown]
# # **Exercise**
#
# Analyse the trip duration along the different hours of a day. We would like to find answers to questions like:
#
# * Is there a period of the day where the trips are longer o shorter?
# * How do you compare the trips by user type or gender?

# %% [markdown]
# # **Exercise**
#
# Define and solve an interesting question about the dataset we have been working on.
