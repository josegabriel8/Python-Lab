# %% [markdown]
#  <img src="https://upload.wikimedia.org/wikipedia/commons/e/ed/Pandas_logo.svg" alt="Panda Logo" width="500">
#
# `Pandas` is a `Python` module for data manipulation and analysis widely used all around the world both in universities and companies. We will show how easy is to work with data in notebooks using a few lines of `pandas` code.
#
# https://pandas.pydata.org/

# %% [markdown]
# As usual, let's load a dataset to work with.

# %%
from vega_datasets import data
dfr = data.la_riots()
dfr
# Out:
#         first_name last_name   age  gender    race death_date  \
# 0         Cesar A.   Aguilar  18.0    Male  Latino 1992-04-30
# 1           George   Alvarez  42.0    Male  Latino 1992-05-01
# 2           Wilson   Alvarez  40.0    Male  Latino 1992-05-23
# 3         Brian E.    Andrew  30.0    Male   Black 1992-04-30
# 4           Vivian    Austin  87.0  Female   Black 1992-05-03
# ..             ...       ...   ...     ...     ...        ...
# 58        Fredrick      Ward  20.0    Male   Black 1992-05-02
# 59        Louis A.    Watson  18.0    Male   Black 1992-04-29
# 60       Elbert O.   Wilkins  33.0    Male   Black 1992-04-30
# 61         John H.   Willers  37.0    Male   White 1992-04-29
# 62  Willie Bernard  Williams  29.0    Male   Black 1992-04-29
#
#                          address         neighborhood  \
# 0                2009 W. 6th St.             Westlake
# 1         Main & College streets            Chinatown
# 2            3100 Rosecrans Ave.            Hawthorne
# 3    Rosecrans & Chester avenues              Compton
# 4               1600 W. 60th St.         Harvard Park
# ..                           ...                  ...
# 58             11932 Cometa Ave.              Pacoima
# 59          4365 S. Vermont Ave.       Vermont Square
# 60  Western Avenue & 92nd Street        Gramercy Park
# 61         10621 Sepulveda Blvd.        Mission Hills
# 62        Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude
# 0   Officer-involved shooting -118.273976  34.059281
# 1            Not riot-related -118.234098  34.062690
# 2                    Homicide -118.326816  33.901662
# 3   Officer-involved shooting -118.215390  33.903457
# 4                       Death -118.304741  33.985667
# ..                        ...         ...        ...
# 58                   Homicide -118.412778  34.287098
# 59                   Homicide -118.291557  34.005244
# 60                   Homicide -118.310004  33.952767
# 61                   Homicide -118.467770  34.263184
# 62                      Death -118.308952  33.982363
#
# [63 rows x 11 columns]

# %% [markdown]
# # Selecting columns

# %% [markdown]
# On occasions we want to select a few columns to work with.

# %%
dfr.columns
# Out:
# Index(['first_name', 'last_name', 'age', 'gender', 'race', 'death_date',
#        'address', 'neighborhood', 'type', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# We can use the name of the columns we want. Notice the syntax!

# %%
dfr['age']
# Out:
# 0     18.0
# 1     42.0
# 2     40.0
# 3     30.0
# 4     87.0
#       ...
# 58    20.0
# 59    18.0
# 60    33.0
# 61    37.0
# 62    29.0
# Name: age, Length: 63, dtype: float64

# %%
dfr[['first_name','last_name']]
# Out:
#         first_name last_name
# 0         Cesar A.   Aguilar
# 1           George   Alvarez
# 2           Wilson   Alvarez
# 3         Brian E.    Andrew
# 4           Vivian    Austin
# ..             ...       ...
# 58        Fredrick      Ward
# 59        Louis A.    Watson
# 60       Elbert O.   Wilkins
# 61         John H.   Willers
# 62  Willie Bernard  Williams
#
# [63 rows x 2 columns]

# %% [markdown]
# Conversely, we can name the columns we are not interested in:

# %%
dfr.drop(columns=['first_name', 'last_name'])
# Out:
#      age  gender    race death_date                       address  \
# 0   18.0    Male  Latino 1992-04-30               2009 W. 6th St.
# 1   42.0    Male  Latino 1992-05-01        Main & College streets
# 2   40.0    Male  Latino 1992-05-23           3100 Rosecrans Ave.
# 3   30.0    Male   Black 1992-04-30   Rosecrans & Chester avenues
# 4   87.0  Female   Black 1992-05-03              1600 W. 60th St.
# ..   ...     ...     ...        ...                           ...
# 58  20.0    Male   Black 1992-05-02             11932 Cometa Ave.
# 59  18.0    Male   Black 1992-04-29          4365 S. Vermont Ave.
# 60  33.0    Male   Black 1992-04-30  Western Avenue & 92nd Street
# 61  37.0    Male   White 1992-04-29         10621 Sepulveda Blvd.
# 62  29.0    Male   Black 1992-04-29        Gage & Western avenues
#
#            neighborhood                       type   longitude   latitude
# 0              Westlake  Officer-involved shooting -118.273976  34.059281
# 1             Chinatown           Not riot-related -118.234098  34.062690
# 2             Hawthorne                   Homicide -118.326816  33.901662
# 3               Compton  Officer-involved shooting -118.215390  33.903457
# 4          Harvard Park                      Death -118.304741  33.985667
# ..                  ...                        ...         ...        ...
# 58              Pacoima                   Homicide -118.412778  34.287098
# 59       Vermont Square                   Homicide -118.291557  34.005244
# 60        Gramercy Park                   Homicide -118.310004  33.952767
# 61        Mission Hills                   Homicide -118.467770  34.263184
# 62  Chesterfield Square                      Death -118.308952  33.982363
#
# [63 rows x 9 columns]

# %% [markdown]
# But selection or dropping do not alter the original dataframe.

# %%
dfr

# %% [markdown]
# The result of the previous operations can be assigned to a new dataframe variable.

# %%
dfr_selected = dfr.drop(columns=['first_name', 'last_name'])

# %%
dfr_selected
# Out:
#      age  gender    race death_date                       address  \
# 0   18.0    Male  Latino 1992-04-30               2009 W. 6th St.
# 1   42.0    Male  Latino 1992-05-01        Main & College streets
# 2   40.0    Male  Latino 1992-05-23           3100 Rosecrans Ave.
# 3   30.0    Male   Black 1992-04-30   Rosecrans & Chester avenues
# 4   87.0  Female   Black 1992-05-03              1600 W. 60th St.
# ..   ...     ...     ...        ...                           ...
# 58  20.0    Male   Black 1992-05-02             11932 Cometa Ave.
# 59  18.0    Male   Black 1992-04-29          4365 S. Vermont Ave.
# 60  33.0    Male   Black 1992-04-30  Western Avenue & 92nd Street
# 61  37.0    Male   White 1992-04-29         10621 Sepulveda Blvd.
# 62  29.0    Male   Black 1992-04-29        Gage & Western avenues
#
#            neighborhood                       type   longitude   latitude
# 0              Westlake  Officer-involved shooting -118.273976  34.059281
# 1             Chinatown           Not riot-related -118.234098  34.062690
# 2             Hawthorne                   Homicide -118.326816  33.901662
# 3               Compton  Officer-involved shooting -118.215390  33.903457
# 4          Harvard Park                      Death -118.304741  33.985667
# ..                  ...                        ...         ...        ...
# 58              Pacoima                   Homicide -118.412778  34.287098
# 59       Vermont Square                   Homicide -118.291557  34.005244
# 60        Gramercy Park                   Homicide -118.310004  33.952767
# 61        Mission Hills                   Homicide -118.467770  34.263184
# 62  Chesterfield Square                      Death -118.308952  33.982363
#
# [63 rows x 9 columns]

# %%
dfr_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           62 non-null     float64
#  1   gender        63 non-null     object
#  2   race          63 non-null     object
#  3   death_date    63 non-null     datetime64[ns]
#  4   address       63 non-null     object
#  5   neighborhood  63 non-null     object
#  6   type          63 non-null     object
#  7   longitude     63 non-null     float64
#  8   latitude      63 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 4.6+ KB

# %% [markdown]
# Another option `pandas` has, is to select the columns of a given type:

# %%
dfr.select_dtypes('object')
# Out:
#         first_name last_name  gender    race                       address  \
# 0         Cesar A.   Aguilar    Male  Latino               2009 W. 6th St.
# 1           George   Alvarez    Male  Latino        Main & College streets
# 2           Wilson   Alvarez    Male  Latino           3100 Rosecrans Ave.
# 3         Brian E.    Andrew    Male   Black   Rosecrans & Chester avenues
# 4           Vivian    Austin  Female   Black              1600 W. 60th St.
# ..             ...       ...     ...     ...                           ...
# 58        Fredrick      Ward    Male   Black             11932 Cometa Ave.
# 59        Louis A.    Watson    Male   Black          4365 S. Vermont Ave.
# 60       Elbert O.   Wilkins    Male   Black  Western Avenue & 92nd Street
# 61         John H.   Willers    Male   White         10621 Sepulveda Blvd.
# 62  Willie Bernard  Williams    Male   Black        Gage & Western avenues
#
#            neighborhood                       type
# 0              Westlake  Officer-involved shooting
# 1             Chinatown           Not riot-related
# 2             Hawthorne                   Homicide
# 3               Compton  Officer-involved shooting
# 4          Harvard Park                      Death
# ..                  ...                        ...
# 58              Pacoima                   Homicide
# 59       Vermont Square                   Homicide
# 60        Gramercy Park                   Homicide
# 61        Mission Hills                   Homicide
# 62  Chesterfield Square                      Death
#
# [63 rows x 7 columns]

# %% [markdown]
# ## **Exercise**
#
# In the `dfr` dataframe, select the columns that do not have a numerical type.

# %%
dfr.select_dtypes(exclude='float')
# Out:
#         first_name last_name  gender    race death_date  \
# 0         Cesar A.   Aguilar    Male  Latino 1992-04-30
# 1           George   Alvarez    Male  Latino 1992-05-01
# 2           Wilson   Alvarez    Male  Latino 1992-05-23
# 3         Brian E.    Andrew    Male   Black 1992-04-30
# 4           Vivian    Austin  Female   Black 1992-05-03
# ..             ...       ...     ...     ...        ...
# 58        Fredrick      Ward    Male   Black 1992-05-02
# 59        Louis A.    Watson    Male   Black 1992-04-29
# 60       Elbert O.   Wilkins    Male   Black 1992-04-30
# 61         John H.   Willers    Male   White 1992-04-29
# 62  Willie Bernard  Williams    Male   Black 1992-04-29
#
#                          address         neighborhood  \
# 0                2009 W. 6th St.             Westlake
# 1         Main & College streets            Chinatown
# 2            3100 Rosecrans Ave.            Hawthorne
# 3    Rosecrans & Chester avenues              Compton
# 4               1600 W. 60th St.         Harvard Park
# ..                           ...                  ...
# 58             11932 Cometa Ave.              Pacoima
# 59          4365 S. Vermont Ave.       Vermont Square
# 60  Western Avenue & 92nd Street        Gramercy Park
# 61         10621 Sepulveda Blvd.        Mission Hills
# 62        Gage & Western avenues  Chesterfield Square
#
#                          type
# 0   Officer-involved shooting
# 1            Not riot-related
# 2                    Homicide
# 3   Officer-involved shooting
# 4                       Death
# ..                        ...
# 58                   Homicide
# 59                   Homicide
# 60                   Homicide
# 61                   Homicide
# 62                      Death
#
# [63 rows x 8 columns]

# %% [markdown]
# ## **Exercise**
#
# Select the columns in the dataframe `dfr` that satisfy a condition. For instance, the columns whose name has a 'g'; or columns that contains the word 'name'...

# %%
dfr[[name for name in dfr.columns if len(name)<5]]
# Out:
#      age    race                       type
# 0   18.0  Latino  Officer-involved shooting
# 1   42.0  Latino           Not riot-related
# 2   40.0  Latino                   Homicide
# 3   30.0   Black  Officer-involved shooting
# 4   87.0   Black                      Death
# ..   ...     ...                        ...
# 58  20.0   Black                   Homicide
# 59  18.0   Black                   Homicide
# 60  33.0   Black                   Homicide
# 61  37.0   White                   Homicide
# 62  29.0   Black                      Death
#
# [63 rows x 3 columns]

# %% [markdown]
# # Selectig rows

# %% [markdown]
# ## Sample

# %% [markdown]
# A quite frequent operation with data is to select rows in a dataframe. For instance, to get a sample.
#
# In `pandas` we can use the function `sample()`

# %%
dfr.sample(5)
# Out:
#    first_name last_name   age  gender    race death_date  \
# 26      Betty   Jackson  56.0  Female   Black 1992-05-01
# 49       Imad    Sharaf  31.0    Male   Black 1992-05-03
# 58   Fredrick      Ward  20.0    Male   Black 1992-05-02
# 44    Hugo G.   Ramirez  23.0    Male  Latino 1992-05-03
# 11       John   Doe #80   NaN    Male   White 1992-05-02
#
#                                               address     neighborhood  \
# 26                                Main & 51st streets       South Park
# 49  San Diego Freeway & San Fernando Mission Boule...    Mission Hills
# 58                                  11932 Cometa Ave.          Pacoima
# 44                                     12732 Bess St.     Baldwin Park
# 11                 5800 block of South Vermont Avenue  Vermont-Slauson
#
#                 type   longitude   latitude
# 26             Death -118.273931  33.996522
# 49  Not riot-related -118.471745  34.271856
# 58          Homicide -118.412778  34.287098
# 44  Not riot-related -117.997106  34.070238
# 11          Homicide -118.291495  33.989399

# %%
dfr.sample(frac=0.1)
# Out:
#     first_name last_name   age  gender    race death_date  \
# 36   Arturo C.   Miranda  23.0    Male  Latino 1992-04-29
# 57  Eduardo C.      Vela  33.0    Male  Latino 1992-04-29
# 38      Nissar   Mustafa  20.0    Male   White 1992-08-12
# 32    Lucie R.  Maronian  51.0  Female   White 1992-05-01
# 27  Dennis Ray   Jackson  38.0    Male   Black 1992-04-30
# 17     Jose L.    Garcia  15.0    Male  Latino 1992-04-30
#
#                               address     neighborhood  \
# 36      120th Street & Central Avenue    Green Meadows
# 57  5100 block of West Slauson Avenue   Ladera Heights
# 38               1601 S. Western Ave.  Harvard Heights
# 32  1800 block of East New York Drive         Altadena
# 27                   11322 Alvaro St.            Watts
# 17                 1005 S. Fresno St.    Boyle Heights
#
#                          type   longitude   latitude
# 36                   Homicide -118.254343  33.923730
# 57                   Homicide -118.368720  33.987604
# 38                   Homicide -118.309034  34.043554
# 32                   Homicide -118.113436  34.178505
# 27  Officer-involved shooting -118.253757  33.932292
# 17           Not riot-related -118.207042  34.027553

# %%
dfr.sample?

# %% [markdown]
# ## Index

# %% [markdown]
# On some occasions we do not want random rows, but quite on the contrary we want to select very specific rows.

# %%
dfr.loc[16]
# Out:
# first_name                                  Kevin A.
# last_name                                   Evanahen
# age                                             24.0
# gender                                          Male
# race                                           White
# death_date                       1992-05-01 00:00:00
# address         Braddock Drive & Inglewood Boulevard
# neighborhood                                 Del Rey
# type                                        Homicide
# longitude                                -118.414453
# latitude                                   33.992672
# Name: 16, dtype: object

# %%
dfr.loc[16:20]
# Out:
#    first_name      last_name   age gender    race death_date  \
# 16   Kevin A.       Evanahen  24.0   Male   White 1992-05-01
# 17    Jose L.         Garcia  15.0   Male  Latino 1992-04-30
# 18       Mark         Garcia  15.0   Male  Latino 1992-04-30
# 19      Elias  Garcia Rivera  32.0   Male  Latino 1992-12-16
# 20    Andreas        Garnica  36.0   Male  Latino 1992-04-30
#
#                                  address   neighborhood  \
# 16  Braddock Drive & Inglewood Boulevard        Del Rey
# 17                    1005 S. Fresno St.  Boyle Heights
# 18           10700 block of Burin Avenue         Lennox
# 19                     12834 Vanowen St.    Valley Glen
# 20                    2034 W. Pico Blvd.     Pico-Union
#
#                          type   longitude   latitude
# 16                   Homicide -118.414453  33.992672
# 17           Not riot-related -118.207042  34.027553
# 18  Officer-involved shooting -118.353766  33.938954
# 19                   Homicide -118.413791  34.193934
# 20           Not riot-related -118.281879  34.046844

# %%
dfr.loc[16:25:3]
# Out:
#     first_name      last_name   age gender    race death_date  \
# 16    Kevin A.       Evanahen  24.0   Male   White 1992-05-01
# 19       Elias  Garcia Rivera  32.0   Male  Latino 1992-12-16
# 22  Matthew D.         Haines  32.0   Male   White 1992-04-30
# 25     Paul D.         Horace  38.0   Male   Black 1992-05-01
#
#                                  address     neighborhood      type  \
# 16  Braddock Drive & Inglewood Boulevard          Del Rey  Homicide
# 19                     12834 Vanowen St.      Valley Glen  Homicide
# 22  Lemon Avenue & Pacific Coast Highway       Long Beach  Homicide
# 25                        1439 E. Walnut  Central-Alameda  Homicide
#
#      longitude   latitude
# 16 -118.414453  33.992672
# 19 -118.413791  34.193934
# 22 -118.178511  33.789857
# 25 -118.247414  34.021735

# %%
list(range(10,13))+[15,16]
# Out:
# [10, 11, 12, 15, 16]

# %%
dfr.loc[list(range(10,13))+[15,16]]
# Out:
#    first_name  last_name   age  gender    race death_date  \
# 10    Gregory  Davis Jr.  15.0    Male   Black 1992-04-30
# 11       John    Doe #80   NaN    Male   White 1992-05-02
# 12      Harry     Doller  56.0    Male   White 1992-05-01
# 15      Juana   Espinosa  65.0  Female  Latino 1992-05-02
# 16   Kevin A.   Evanahen  24.0    Male   White 1992-05-01
#
#                                  address     neighborhood              type  \
# 10          Vermont Avenue & 43rd Street   Vermont Square          Homicide
# 11    5800 block of South Vermont Avenue  Vermont-Slauson          Homicide
# 12           3500 block of Winslow Drive      Silver Lake  Not riot-related
# 15                  7608 S. Compton Ave.          Compton          Homicide
# 16  Braddock Drive & Inglewood Boulevard          Del Rey          Homicide
#
#      longitude   latitude
# 10 -118.291549  34.005485
# 11 -118.291495  33.989399
# 12 -118.278763  34.087788
# 15 -118.246188  33.919821
# 16 -118.414453  33.992672

# %% [markdown]
# On many occasions we do not want/need to know the index of the rows, we want/need instead to select all the rows that satisfy some property. Let's see how to select rows by using different criteria.

# %% [markdown]
# ## Numerical criteria

# %% [markdown]
# In the dataframe `dfr`, imagine we want to select all rows for which the `age` value satisfy some property, for instance:

# %%
dfr[dfr.age>=56]
# Out:
#    first_name last_name   age  gender    race death_date  \
# 4      Vivian    Austin  87.0  Female   Black 1992-05-03
# 12      Harry    Doller  56.0    Male   White 1992-05-01
# 15      Juana  Espinosa  65.0  Female  Latino 1992-05-02
# 26      Betty   Jackson  56.0  Female   Black 1992-05-01
# 45      Aaron  Ratinoff  68.0    Male   White 1992-05-01
#
#                         address  neighborhood              type   longitude  \
# 4              1600 W. 60th St.  Harvard Park             Death -118.304741
# 12  3500 block of Winslow Drive   Silver Lake  Not riot-related -118.278763
# 15         7608 S. Compton Ave.       Compton          Homicide -118.246188
# 26          Main & 51st streets    South Park             Death -118.273931
# 45          11690 Gateway Blvd.      Sawtelle          Homicide -118.443100
#
#      latitude
# 4   33.985667
# 12  34.087788
# 15  33.919821
# 26  33.996522
# 45  34.028655

# %% [markdown]
# As we have already commented, if we want to keep the resulting dataframe for further processing, we have to define a new variable.

# %%
dfr_age50 = dfr[dfr.age>50]
dfr_age50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 4 to 55
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    7 non-null      object
#  1   last_name     7 non-null      object
#  2   age           7 non-null      float64
#  3   gender        7 non-null      object
#  4   race          7 non-null      object
#  5   death_date    7 non-null      datetime64[ns]
#  6   address       7 non-null      object
#  7   neighborhood  7 non-null      object
#  8   type          7 non-null      object
#  9   longitude     7 non-null      float64
#  10  latitude      7 non-null      float64
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 672.0+ bytes

# %% [markdown]
# We can select an age range also:

# %%
dfr[dfr.age.between(30,40)]
# Out:
#     first_name      last_name   age  gender    race death_date  \
# 2       Wilson        Alvarez  40.0    Male  Latino 1992-05-23
# 3     Brian E.         Andrew  30.0    Male   Black 1992-04-30
# 7      Patrick         Bettan  30.0    Male   White 1992-04-30
# 13    Kevin J.        Edwards  35.0    Male   Black 1992-04-30
# 19       Elias  Garcia Rivera  32.0    Male  Latino 1992-12-16
# 20     Andreas        Garnica  36.0    Male  Latino 1992-04-30
# 21      Meeker         Gibson  35.0    Male   Black 1992-05-01
# 22  Matthew D.         Haines  32.0    Male   White 1992-04-30
# 23      Jimmie         Harris  38.0    Male   Black 1992-04-29
# 25     Paul D.         Horace  38.0    Male   Black 1992-05-01
# 27  Dennis Ray        Jackson  38.0    Male   Black 1992-04-30
# 30    Frank D.          Lopez  36.0    Male  Latino 1992-04-30
# 35   Alfred V.         Miller  32.0    Male   Black 1992-05-01
# 42     Juanita       Pettaway  37.0  Female   Black 1992-04-30
# 47     William           Ross  33.0    Male   White 1992-05-01
# 49        Imad         Sharaf  31.0    Male   Black 1992-05-03
# 52  Anthony J.         Taylor  31.0    Male   Black 1992-04-30
# 57  Eduardo C.           Vela  33.0    Male  Latino 1992-04-29
# 60   Elbert O.        Wilkins  33.0    Male   Black 1992-04-30
# 61     John H.        Willers  37.0    Male   White 1992-04-29
#
#                                               address         neighborhood  \
# 2                                 3100 Rosecrans Ave.            Hawthorne
# 3                         Rosecrans & Chester avenues              Compton
# 7                               2740 W. Olympic Blvd.            Koreatown
# 13                                 614 S. Locust Ave.              Compton
# 19                                  12834 Vanowen St.          Valley Glen
# 20                                 2034 W. Pico Blvd.           Pico-Union
# 21                             Holt & Loranne avenues               Pomona
# 22               Lemon Avenue & Pacific Coast Highway           Long Beach
# 23                  Avalon Boulevard & Slauson Avenue           South Park
# 25                                     1439 E. Walnut      Central-Alameda
# 27                                   11322 Alvaro St.                Watts
# 30                       16th Street & Central Avenue             Downtown
# 35                  Florence Avenue & Cimarron Street  Chesterfield Square
# 42             Santa Monica Boulevard & Seward Street            Hollywood
# 47                                    2882 W. 9th St.            Koreatown
# 49  San Diego Freeway & San Fernando Mission Boule...        Mission Hills
# 52                                   11322 Alvaro St.                Watts
# 57                  5100 block of West Slauson Avenue       Ladera Heights
# 60                       Western Avenue & 92nd Street        Gramercy Park
# 61                              10621 Sepulveda Blvd.        Mission Hills
#
#                          type   longitude   latitude
# 2                    Homicide -118.326816  33.901662
# 3   Officer-involved shooting -118.215390  33.903457
# 7                    Homicide -118.293181  34.052068
# 13           Not riot-related -118.200252  33.892421
# 19                   Homicide -118.413791  34.193934
# 20           Not riot-related -118.281879  34.046844
# 21                   Homicide -117.730647  34.062846
# 22                   Homicide -118.178511  33.789857
# 23                      Death -118.265199  33.989245
# 25                   Homicide -118.247414  34.021735
# 27  Officer-involved shooting -118.253757  33.932292
# 30                   Homicide -118.248765  34.026427
# 35                   Homicide -118.315737  33.974591
# 42                      Death -118.333177  34.090696
# 47                   Homicide -118.291274  34.055690
# 49           Not riot-related -118.471745  34.271856
# 52  Officer-involved shooting -118.253197  33.931463
# 57                   Homicide -118.368720  33.987604
# 60                   Homicide -118.310004  33.952767
# 61                   Homicide -118.467770  34.263184

# %% [markdown]
# ### **Exercise**
#
# Select rows in `dfr` whose age value are in the fourth quartile.

# %%
dfr[dfr.age>=dfr.age.quantile(0.75)]
# Out:
#     first_name      last_name   age  gender    race death_date  \
# 1       George        Alvarez  42.0    Male  Latino 1992-05-01
# 2       Wilson        Alvarez  40.0    Male  Latino 1992-05-23
# 4       Vivian         Austin  87.0  Female   Black 1992-05-03
# 6        Carol         Benson  42.0  Female   Black 1992-05-02
# 8       Hector         Castro  49.0    Male  Latino 1992-04-30
# 12       Harry         Doller  56.0    Male   White 1992-05-01
# 13    Kevin J.        Edwards  35.0    Male   Black 1992-04-30
# 14      Howard        Epstein  45.0    Male   White 1992-04-30
# 15       Juana       Espinosa  65.0  Female  Latino 1992-05-02
# 19       Elias  Garcia Rivera  32.0    Male  Latino 1992-12-16
# 20     Andreas        Garnica  36.0    Male  Latino 1992-04-30
# 21      Meeker         Gibson  35.0    Male   Black 1992-05-01
# 22  Matthew D.         Haines  32.0    Male   White 1992-04-30
# 23      Jimmie         Harris  38.0    Male   Black 1992-04-29
# 25     Paul D.         Horace  38.0    Male   Black 1992-05-01
# 26       Betty        Jackson  56.0  Female   Black 1992-05-01
# 27  Dennis Ray        Jackson  38.0    Male   Black 1992-04-30
# 30    Frank D.          Lopez  36.0    Male  Latino 1992-04-30
# 32    Lucie R.       Maronian  51.0  Female   White 1992-05-01
# 34      Ira F.        McCurry  45.0    Male   White 1992-04-30
# 35   Alfred V.         Miller  32.0    Male   Black 1992-05-01
# 42     Juanita       Pettaway  37.0  Female   Black 1992-04-30
# 45       Aaron       Ratinoff  68.0    Male   White 1992-05-01
# 47     William           Ross  33.0    Male   White 1992-05-01
# 49        Imad         Sharaf  31.0    Male   Black 1992-05-03
# 52  Anthony J.         Taylor  31.0    Male   Black 1992-04-30
# 53      Dwight         Taylor  42.0    Male   Black 1992-04-29
# 55     Wallace           Tope  54.0    Male   White 1993-11-24
# 57  Eduardo C.           Vela  33.0    Male  Latino 1992-04-29
# 60   Elbert O.        Wilkins  33.0    Male   Black 1992-04-30
# 61     John H.        Willers  37.0    Male   White 1992-04-29
#
#                                               address         neighborhood  \
# 1                              Main & College streets            Chinatown
# 2                                 3100 Rosecrans Ave.            Hawthorne
# 4                                    1600 W. 60th St.         Harvard Park
# 6                  Harbor Freeway near Slauson Avenue           South Park
# 8                           Vermont & Leeward avenues            Koreatown
# 12                        3500 block of Winslow Drive          Silver Lake
# 13                                 614 S. Locust Ave.              Compton
# 14                              Slauson & 7th avenues            Hyde Park
# 15                               7608 S. Compton Ave.              Compton
# 19                                  12834 Vanowen St.          Valley Glen
# 20                                 2034 W. Pico Blvd.           Pico-Union
# 21                             Holt & Loranne avenues               Pomona
# 22               Lemon Avenue & Pacific Coast Highway           Long Beach
# 23                  Avalon Boulevard & Slauson Avenue           South Park
# 25                                     1439 E. Walnut      Central-Alameda
# 26                                Main & 51st streets           South Park
# 27                                   11322 Alvaro St.                Watts
# 30                       16th Street & Central Avenue             Downtown
# 32                  1800 block of East New York Drive             Altadena
# 34                    Avalon Boulevard & 102nd Street        Green Meadows
# 35                  Florence Avenue & Cimarron Street  Chesterfield Square
# 42             Santa Monica Boulevard & Seward Street            Hollywood
# 45                                11690 Gateway Blvd.             Sawtelle
# 47                                    2882 W. 9th St.            Koreatown
# 49  San Diego Freeway & San Fernando Mission Boule...        Mission Hills
# 52                                   11322 Alvaro St.                Watts
# 53                               4365 S. Vermont Ave.       Vermont Square
# 55                               5510 W. Sunset Blvd.            Hollywood
# 57                  5100 block of West Slauson Avenue       Ladera Heights
# 60                       Western Avenue & 92nd Street        Gramercy Park
# 61                              10621 Sepulveda Blvd.        Mission Hills
#
#                          type   longitude   latitude
# 1            Not riot-related -118.234098  34.062690
# 2                    Homicide -118.326816  33.901662
# 4                       Death -118.304741  33.985667
# 6                       Death -118.280504  33.989168
# 8                    Homicide -118.291654  34.058702
# 12           Not riot-related -118.278763  34.087788
# 13           Not riot-related -118.200252  33.892421
# 14                   Homicide -118.324742  33.989049
# 15                   Homicide -118.246188  33.919821
# 19                   Homicide -118.413791  34.193934
# 20           Not riot-related -118.281879  34.046844
# 21                   Homicide -117.730647  34.062846
# 22                   Homicide -118.178511  33.789857
# 23                      Death -118.265199  33.989245
# 25                   Homicide -118.247414  34.021735
# 26                      Death -118.273931  33.996522
# 27  Officer-involved shooting -118.253757  33.932292
# 30                   Homicide -118.248765  34.026427
# 32                   Homicide -118.113436  34.178505
# 34                   Homicide -118.265163  33.943756
# 35                   Homicide -118.315737  33.974591
# 42                      Death -118.333177  34.090696
# 45                   Homicide -118.443100  34.028655
# 47                   Homicide -118.291274  34.055690
# 49           Not riot-related -118.471745  34.271856
# 52  Officer-involved shooting -118.253197  33.931463
# 53                   Homicide -118.292169  34.004453
# 55                   Homicide -118.309822  34.098082
# 57                   Homicide -118.368720  33.987604
# 60                   Homicide -118.310004  33.952767
# 61                   Homicide -118.467770  34.263184

# %% [markdown]
# ## Date criteria

# %% [markdown]
# If we want to select rows considering a property that depends on date values, the idea is the same: we have to add conditions to that column.

# %%
dfr[dfr['death_date']>('1992-05-03')]
# Out:
#    first_name      last_name   age gender    race death_date  \
# 2      Wilson        Alvarez  40.0   Male  Latino 1992-05-23
# 19      Elias  Garcia Rivera  32.0   Male  Latino 1992-12-16
# 38     Nissar        Mustafa  20.0   Male   White 1992-08-12
# 48    Juan V.        Salgado  20.0   Male  Latino 1992-05-20
# 55    Wallace           Tope  54.0   Male   White 1993-11-24
#
#                             address            neighborhood      type  \
# 2               3100 Rosecrans Ave.               Hawthorne  Homicide
# 19                12834 Vanowen St.             Valley Glen  Homicide
# 38             1601 S. Western Ave.         Harvard Heights  Homicide
# 48  3100 block of South Main Street  Historic South-Central  Homicide
# 55             5510 W. Sunset Blvd.               Hollywood  Homicide
#
#      longitude   latitude
# 2  -118.326816  33.901662
# 19 -118.413791  34.193934
# 38 -118.309034  34.043554
# 48 -118.271379  34.020622
# 55 -118.309822  34.098082

# %% [markdown]
# ### **Exercise**
#
# Select the rows occurred in the month with the largest number of deaths.

# %%
dfr.death_date.dt.month.value_counts().index[0]

dfr[dfr.death_date.dt.month==dfr.death_date.dt.month.value_counts().index[0]]
# Out:
#         first_name  last_name   age  gender    race death_date  \
# 0         Cesar A.    Aguilar  18.0    Male  Latino 1992-04-30
# 3         Brian E.     Andrew  30.0    Male   Black 1992-04-30
# 5         Franklin  Benavidez  27.0    Male  Latino 1992-04-30
# 7          Patrick     Bettan  30.0    Male   White 1992-04-30
# 8           Hector     Castro  49.0    Male  Latino 1992-04-30
# 9         Jerel L.   Channell  26.0    Male   Black 1992-04-30
# 10         Gregory  Davis Jr.  15.0    Male   Black 1992-04-30
# 13        Kevin J.    Edwards  35.0    Male   Black 1992-04-30
# 14          Howard    Epstein  45.0    Male   White 1992-04-30
# 17         Jose L.     Garcia  15.0    Male  Latino 1992-04-30
# 18            Mark     Garcia  15.0    Male  Latino 1992-04-30
# 20         Andreas    Garnica  36.0    Male  Latino 1992-04-30
# 22      Matthew D.     Haines  32.0    Male   White 1992-04-30
# 23          Jimmie     Harris  38.0    Male   Black 1992-04-29
# 24         DeAndre   Harrison  17.0    Male   Black 1992-04-30
# 27      Dennis Ray    Jackson  38.0    Male   Black 1992-04-30
# 28           Tranh        Lam  25.0    Male   Asian 1992-04-30
# 29     Edward Song        Lee  18.0    Male   Asian 1992-04-30
# 30        Frank D.      Lopez  36.0    Male  Latino 1992-04-30
# 31      Darnell R.    Mallory  18.0    Male   Black 1992-04-30
# 34          Ira F.    McCurry  45.0    Male   White 1992-04-30
# 36       Arturo C.    Miranda  23.0    Male  Latino 1992-04-29
# 39          Ernest   Neal Jr.  27.0    Male   Black 1992-04-30
# 40         Anthony   Netherly  21.0    Male   Black 1992-04-30
# 42         Juanita   Pettaway  37.0  Female   Black 1992-04-30
# 43         Juan A.     Pineda  20.0    Male  Latino 1992-04-30
# 51       George A.       Sosa  20.0    Male  Latino 1992-04-30
# 52      Anthony J.     Taylor  31.0    Male   Black 1992-04-30
# 53          Dwight     Taylor  42.0    Male   Black 1992-04-29
# 54        James L.     Taylor  26.0    Male   Black 1992-04-30
# 56  Edward Anthony    Travens  15.0    Male   White 1992-04-29
# 57      Eduardo C.       Vela  33.0    Male  Latino 1992-04-29
# 59        Louis A.     Watson  18.0    Male   Black 1992-04-29
# 60       Elbert O.    Wilkins  33.0    Male   Black 1992-04-30
# 61         John H.    Willers  37.0    Male   White 1992-04-29
# 62  Willie Bernard   Williams  29.0    Male   Black 1992-04-29
#
#                                               address         neighborhood  \
# 0                                     2009 W. 6th St.             Westlake
# 3                         Rosecrans & Chester avenues              Compton
# 5                                4404 S. Western Ave.       Vermont Square
# 7                               2740 W. Olympic Blvd.            Koreatown
# 8                           Vermont & Leeward avenues            Koreatown
# 9              Santa Monica Boulevard & Seward Street            Hollywood
# 10                       Vermont Avenue & 43rd Street       Vermont Square
# 13                                 614 S. Locust Ave.              Compton
# 14                              Slauson & 7th avenues            Hyde Park
# 17                                 1005 S. Fresno St.        Boyle Heights
# 18                        10700 block of Burin Avenue               Lennox
# 20                                 2034 W. Pico Blvd.           Pico-Union
# 22               Lemon Avenue & Pacific Coast Highway           Long Beach
# 23                  Avalon Boulevard & Slauson Avenue           South Park
# 24                      Central Avenue & 112th Street        Green Meadows
# 27                                   11322 Alvaro St.                Watts
# 28             Willowbrook Avenue & Alondra Boulevard              Compton
# 29                      Hobart Boulevard & 3rd Street            Koreatown
# 30                       16th Street & Central Avenue             Downtown
# 31             Santa Monica Boulevard & Seward Street            Hollywood
# 34                    Avalon Boulevard & 102nd Street        Green Meadows
# 36                      120th Street & Central Avenue        Green Meadows
# 39                       Western Avenue & 92nd Street        Gramercy Park
# 40                           San Pedro & 78th streets             Florence
# 42             Santa Monica Boulevard & Seward Street            Hollywood
# 43                            4028 Santa Monica Blvd.          Silver Lake
# 51                      2600 block of Florence Avenue      Huntington Park
# 52                                   11322 Alvaro St.                Watts
# 53                               4365 S. Vermont Ave.       Vermont Square
# 54                                  5213 Sunset Blvd.       East Hollywood
# 56  San Fernando Road & San Fernando Mission Boule...         San Fernando
# 57                  5100 block of West Slauson Avenue       Ladera Heights
# 59                               4365 S. Vermont Ave.       Vermont Square
# 60                       Western Avenue & 92nd Street        Gramercy Park
# 61                              10621 Sepulveda Blvd.        Mission Hills
# 62                             Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude
# 0   Officer-involved shooting -118.273976  34.059281
# 3   Officer-involved shooting -118.215390  33.903457
# 5   Officer-involved shooting -118.308821  34.003473
# 7                    Homicide -118.293181  34.052068
# 8                    Homicide -118.291654  34.058702
# 9                       Death -118.332378  34.091298
# 10                   Homicide -118.291549  34.005485
# 13           Not riot-related -118.200252  33.892421
# 14                   Homicide -118.324742  33.989049
# 17           Not riot-related -118.207042  34.027553
# 18  Officer-involved shooting -118.353766  33.938954
# 20           Not riot-related -118.281879  34.046844
# 22                   Homicide -118.178511  33.789857
# 23                      Death -118.265199  33.989245
# 24  Officer-involved shooting -118.254295  33.929472
# 27  Officer-involved shooting -118.253757  33.932292
# 28                   Homicide -118.223867  33.888594
# 29                   Homicide -118.305439  34.068985
# 30                   Homicide -118.248765  34.026427
# 31                      Death -118.334138  34.090972
# 34                   Homicide -118.265163  33.943756
# 36                   Homicide -118.254343  33.923730
# 39                   Homicide -118.309006  33.952709
# 40                   Homicide -118.269516  33.968781
# 42                      Death -118.333177  34.090696
# 43                   Homicide -118.281326  34.092221
# 51                   Homicide -118.225181  33.974180
# 52  Officer-involved shooting -118.253197  33.931463
# 53                   Homicide -118.292169  34.004453
# 54                   Homicide -118.303756  34.098248
# 56           Not riot-related -118.443003  34.284187
# 57                   Homicide -118.368720  33.987604
# 59                   Homicide -118.291557  34.005244
# 60                   Homicide -118.310004  33.952767
# 61                   Homicide -118.467770  34.263184
# 62                      Death -118.308952  33.982363

# %% [markdown]
# ## String criteria

# %% [markdown]
# Similarly, if the criteria to row selection depends on string values, it is natural to use the functions we saw to work with string columns.
#
# For instance, consider this method: `.str.contains()`

# %%
dfr[dfr.neighborhood.str.contains('Hollywood')]
# Out:
#     first_name  last_name   age  gender    race death_date  \
# 9     Jerel L.   Channell  26.0    Male   Black 1992-04-30
# 31  Darnell R.    Mallory  18.0    Male   Black 1992-04-30
# 42     Juanita   Pettaway  37.0  Female   Black 1992-04-30
# 50        Jose  Solorzano  25.0    Male  Latino 1992-05-01
# 54    James L.     Taylor  26.0    Male   Black 1992-04-30
# 55     Wallace       Tope  54.0    Male   White 1993-11-24
#
#                                     address    neighborhood      type  \
# 9    Santa Monica Boulevard & Seward Street       Hollywood     Death
# 31   Santa Monica Boulevard & Seward Street       Hollywood     Death
# 42   Santa Monica Boulevard & Seward Street       Hollywood     Death
# 50  Vermont Avenue & Santa Monica Boulevard  East Hollywood  Homicide
# 54                        5213 Sunset Blvd.  East Hollywood  Homicide
# 55                     5510 W. Sunset Blvd.       Hollywood  Homicide
#
#      longitude   latitude
# 9  -118.332378  34.091298
# 31 -118.334138  34.090972
# 42 -118.333177  34.090696
# 50 -118.291755  34.090868
# 54 -118.303756  34.098248
# 55 -118.309822  34.098082

# %% [markdown]
# Or, this other method...

# %%
dfr[dfr.last_name.str.startswith('C')]
# Out:
#   first_name last_name   age gender    race death_date  \
# 8     Hector    Castro  49.0   Male  Latino 1992-04-30
# 9   Jerel L.  Channell  26.0   Male   Black 1992-04-30
#
#                                   address neighborhood      type   longitude  \
# 8               Vermont & Leeward avenues    Koreatown  Homicide -118.291654
# 9  Santa Monica Boulevard & Seward Street    Hollywood     Death -118.332378
#
#     latitude
# 8  34.058702
# 9  34.091298

# %% [markdown]
# ### **Exercise**
#
# Select the rows in `dfr` that occurred in a crossroad.

# %%
dfr[dfr.address.str.contains('&')]
# Out:
#         first_name  last_name   age  gender    race death_date  \
# 1           George    Alvarez  42.0    Male  Latino 1992-05-01
# 3         Brian E.     Andrew  30.0    Male   Black 1992-04-30
# 8           Hector     Castro  49.0    Male  Latino 1992-04-30
# 9         Jerel L.   Channell  26.0    Male   Black 1992-04-30
# 10         Gregory  Davis Jr.  15.0    Male   Black 1992-04-30
# 14          Howard    Epstein  45.0    Male   White 1992-04-30
# 16        Kevin A.   Evanahen  24.0    Male   White 1992-05-01
# 21          Meeker     Gibson  35.0    Male   Black 1992-05-01
# 22      Matthew D.     Haines  32.0    Male   White 1992-04-30
# 23          Jimmie     Harris  38.0    Male   Black 1992-04-29
# 24         DeAndre   Harrison  17.0    Male   Black 1992-04-30
# 26           Betty    Jackson  56.0  Female   Black 1992-05-01
# 28           Tranh        Lam  25.0    Male   Asian 1992-04-30
# 29     Edward Song        Lee  18.0    Male   Asian 1992-04-30
# 30        Frank D.      Lopez  36.0    Male  Latino 1992-04-30
# 31      Darnell R.    Mallory  18.0    Male   Black 1992-04-30
# 33   Howard Eugene     Martin  22.0    Male   Black 1992-05-03
# 34          Ira F.    McCurry  45.0    Male   White 1992-04-30
# 35       Alfred V.     Miller  32.0    Male   Black 1992-05-01
# 36       Arturo C.    Miranda  23.0    Male  Latino 1992-04-29
# 39          Ernest   Neal Jr.  27.0    Male   Black 1992-04-30
# 40         Anthony   Netherly  21.0    Male   Black 1992-04-30
# 41      Charles W.      Orebo  21.0    Male   Black 1992-05-01
# 42         Juanita   Pettaway  37.0  Female   Black 1992-04-30
# 46       Victor R.      Rivas  26.0    Male  Latino 1992-05-03
# 49            Imad     Sharaf  31.0    Male   Black 1992-05-03
# 50            Jose  Solorzano  25.0    Male  Latino 1992-05-01
# 56  Edward Anthony    Travens  15.0    Male   White 1992-04-29
# 60       Elbert O.    Wilkins  33.0    Male   Black 1992-04-30
# 62  Willie Bernard   Williams  29.0    Male   Black 1992-04-29
#
#                                               address         neighborhood  \
# 1                              Main & College streets            Chinatown
# 3                         Rosecrans & Chester avenues              Compton
# 8                           Vermont & Leeward avenues            Koreatown
# 9              Santa Monica Boulevard & Seward Street            Hollywood
# 10                       Vermont Avenue & 43rd Street       Vermont Square
# 14                              Slauson & 7th avenues            Hyde Park
# 16               Braddock Drive & Inglewood Boulevard              Del Rey
# 21                             Holt & Loranne avenues               Pomona
# 22               Lemon Avenue & Pacific Coast Highway           Long Beach
# 23                  Avalon Boulevard & Slauson Avenue           South Park
# 24                      Central Avenue & 112th Street        Green Meadows
# 26                                Main & 51st streets           South Park
# 28             Willowbrook Avenue & Alondra Boulevard              Compton
# 29                      Hobart Boulevard & 3rd Street            Koreatown
# 30                       16th Street & Central Avenue             Downtown
# 31             Santa Monica Boulevard & Seward Street            Hollywood
# 33    near North Los Robles Avenue & Claremont Street             Pasadena
# 34                    Avalon Boulevard & 102nd Street        Green Meadows
# 35                  Florence Avenue & Cimarron Street  Chesterfield Square
# 36                      120th Street & Central Avenue        Green Meadows
# 39                       Western Avenue & 92nd Street        Gramercy Park
# 40                           San Pedro & 78th streets             Florence
# 41                    Florence Avenue & Flower Street             Florence
# 42             Santa Monica Boulevard & Seward Street            Hollywood
# 46                    Pico Boulevard & Vermont Avenue           Pico-Union
# 49  San Diego Freeway & San Fernando Mission Boule...        Mission Hills
# 50            Vermont Avenue & Santa Monica Boulevard       East Hollywood
# 56  San Fernando Road & San Fernando Mission Boule...         San Fernando
# 60                       Western Avenue & 92nd Street        Gramercy Park
# 62                             Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude
# 1            Not riot-related -118.234098  34.062690
# 3   Officer-involved shooting -118.215390  33.903457
# 8                    Homicide -118.291654  34.058702
# 9                       Death -118.332378  34.091298
# 10                   Homicide -118.291549  34.005485
# 14                   Homicide -118.324742  33.989049
# 16                   Homicide -118.414453  33.992672
# 21                   Homicide -117.730647  34.062846
# 22                   Homicide -118.178511  33.789857
# 23                      Death -118.265199  33.989245
# 24  Officer-involved shooting -118.254295  33.929472
# 26                      Death -118.273931  33.996522
# 28                   Homicide -118.223867  33.888594
# 29                   Homicide -118.305439  34.068985
# 30                   Homicide -118.248765  34.026427
# 31                      Death -118.334138  34.090972
# 33  Officer-involved shooting -118.141613  34.166864
# 34                   Homicide -118.265163  33.943756
# 35                   Homicide -118.315737  33.974591
# 36                   Homicide -118.254343  33.923730
# 39                   Homicide -118.309006  33.952709
# 40                   Homicide -118.269516  33.968781
# 41  Officer-involved shooting -118.281290  33.974657
# 42                      Death -118.333177  34.090696
# 46  Officer-involved shooting -118.291583  34.047256
# 49           Not riot-related -118.471745  34.271856
# 50                   Homicide -118.291755  34.090868
# 56           Not riot-related -118.443003  34.284187
# 60                   Homicide -118.310004  33.952767
# 62                      Death -118.308952  33.982363

# %% [markdown]
# ## All together

# %% [markdown]
# The different conditions we have commented so far can be grouped together.
# Let's suppose that we want the rows whose `age` is over 30, `neiborhood` contains `Park` and `gender` is `Female`:

# %%
dfr[(dfr['age']>=20) \ #the \ is for passing to the next line
    & (dfr['neighborhood'].str.contains('Park')) \
    & (dfr['gender']=='Female')]
# Out:
#    first_name last_name   age  gender   race death_date  \
# 4      Vivian    Austin  87.0  Female  Black 1992-05-03
# 6       Carol    Benson  42.0  Female  Black 1992-05-02
# 26      Betty   Jackson  56.0  Female  Black 1992-05-01
#
#                                address  neighborhood   type   longitude  \
# 4                     1600 W. 60th St.  Harvard Park  Death -118.304741
# 6   Harbor Freeway near Slauson Avenue    South Park  Death -118.280504
# 26                 Main & 51st streets    South Park  Death -118.273931
#
#      latitude
# 4   33.985667
# 6   33.989168
# 26  33.996522

# %% [markdown]
# Be careful with the syntax, do not forget the parenthesis!

# %% [markdown]
# ### **Exercise**
#
# Select the rows with: not "White" in the column `race`; that occurred in a  crossroad with "Western" avenue.

# %%
dfr[(dfr['race']!='White') \
    & (dfr['address'].str.contains('&')) \
    & (dfr['address'].str.contains('Western'))]
# Out:
#         first_name last_name   age gender   race death_date  \
# 39          Ernest  Neal Jr.  27.0   Male  Black 1992-04-30
# 60       Elbert O.   Wilkins  33.0   Male  Black 1992-04-30
# 62  Willie Bernard  Williams  29.0   Male  Black 1992-04-29
#
#                          address         neighborhood      type   longitude  \
# 39  Western Avenue & 92nd Street        Gramercy Park  Homicide -118.309006
# 60  Western Avenue & 92nd Street        Gramercy Park  Homicide -118.310004
# 62        Gage & Western avenues  Chesterfield Square     Death -118.308952
#
#      latitude
# 39  33.952709
# 60  33.952767
# 62  33.982363

# %% [markdown]
# # Selecting undefined values

# %% [markdown]
# A very special case we will probably want to select when working with datasets are the null values, also called `nan` values.

# %%
dfr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    63 non-null     object
#  1   last_name     63 non-null     object
#  2   age           62 non-null     float64
#  3   gender        63 non-null     object
#  4   race          63 non-null     object
#  5   death_date    63 non-null     datetime64[ns]
#  6   address       63 non-null     object
#  7   neighborhood  63 non-null     object
#  8   type          63 non-null     object
#  9   longitude     63 non-null     float64
#  10  latitude      63 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 5.5+ KB

# %% [markdown]
# There is a very convenient method that do that:

# %%
dfr[dfr.age.isna()]
# Out:
#    first_name last_name  age gender   race death_date  \
# 11       John   Doe #80  NaN   Male  White 1992-05-02
#
#                                address     neighborhood      type   longitude  \
# 11  5800 block of South Vermont Avenue  Vermont-Slauson  Homicide -118.291495
#
#      latitude
# 11  33.989399

# %% [markdown]
# We can have more complex situations, where `nan` values are spread over different columns in the dataframe. Let's consider another dataframe to illustrate this situation.

# %%
dfc = data.cars()
dfc
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 0         130.0           3504          12.0 1970-01-01     USA
# 1         165.0           3693          11.5 1970-01-01     USA
# 2         150.0           3436          11.0 1970-01-01     USA
# 3         150.0           3433          12.0 1970-01-01     USA
# 4         140.0           3449          10.5 1970-01-01     USA
# ..          ...            ...           ...        ...     ...
# 401        86.0           2790          15.6 1982-01-01     USA
# 402        52.0           2130          24.6 1982-01-01  Europe
# 403        84.0           2295          11.6 1982-01-01     USA
# 404        79.0           2625          18.6 1982-01-01     USA
# 405        82.0           2720          19.4 1982-01-01     USA
#
# [406 rows x 9 columns]

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              406 non-null    object
#  1   Miles_per_Gallon  398 non-null    float64
#  2   Cylinders         406 non-null    int64
#  3   Displacement      406 non-null    float64
#  4   Horsepower        400 non-null    float64
#  5   Weight_in_lbs     406 non-null    int64
#  6   Acceleration      406 non-null    float64
#  7   Year              406 non-null    datetime64[ns]
#  8   Origin            406 non-null    object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(2)
# memory usage: 28.7+ KB

# %%
dfc[dfc.Horsepower.isna()]
# Out:
#                      Name  Miles_per_Gallon  Cylinders  Displacement  \
# 38             ford pinto              25.0          4          98.0
# 133         ford maverick              21.0          6         200.0
# 337  renault lecar deluxe              40.9          4          85.0
# 343    ford mustang cobra              23.6          4         140.0
# 361           renault 18i              34.5          4         100.0
# 382        amc concord dl              23.0          4         151.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 38          NaN           2046          19.0 1971-01-01     USA
# 133         NaN           2875          17.0 1974-01-01     USA
# 337         NaN           1835          17.3 1980-01-01  Europe
# 343         NaN           2905          14.3 1980-01-01     USA
# 361         NaN           2320          15.8 1982-01-01  Europe
# 382         NaN           3035          20.5 1982-01-01     USA

# %% [markdown]
# To show all data with `nan` values we can write:

# %%
dfc[dfc.Miles_per_Gallon.isna() | dfc.Horsepower.isna()]
# Out:
#                                  Name  Miles_per_Gallon  Cylinders  \
# 10               citroen ds-21 pallas               NaN          4
# 11   chevrolet chevelle concours (sw)               NaN          8
# 12                   ford torino (sw)               NaN          8
# 13            plymouth satellite (sw)               NaN          8
# 14                 amc rebel sst (sw)               NaN          8
# 17              ford mustang boss 302               NaN          8
# 38                         ford pinto              25.0          4
# 39        volkswagen super beetle 117               NaN          4
# 133                     ford maverick              21.0          6
# 337              renault lecar deluxe              40.9          4
# 343                ford mustang cobra              23.6          4
# 361                       renault 18i              34.5          4
# 367                         saab 900s               NaN          4
# 382                    amc concord dl              23.0          4
#
#      Displacement  Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 10          133.0       115.0           3090          17.5 1970-01-01  Europe
# 11          350.0       165.0           4142          11.5 1970-01-01     USA
# 12          351.0       153.0           4034          11.0 1970-01-01     USA
# 13          383.0       175.0           4166          10.5 1970-01-01     USA
# 14          360.0       175.0           3850          11.0 1970-01-01     USA
# 17          302.0       140.0           3353           8.0 1970-01-01     USA
# 38           98.0         NaN           2046          19.0 1971-01-01     USA
# 39           97.0        48.0           1978          20.0 1971-01-01  Europe
# 133         200.0         NaN           2875          17.0 1974-01-01     USA
# 337          85.0         NaN           1835          17.3 1980-01-01  Europe
# 343         140.0         NaN           2905          14.3 1980-01-01     USA
# 361         100.0         NaN           2320          15.8 1982-01-01  Europe
# 367         121.0       110.0           2800          15.4 1982-01-01  Europe
# 382         151.0         NaN           3035          20.5 1982-01-01     USA

# %% [markdown]
# Once the `nan` values are identified, some operations can be done. Let's comment two simple ones:
#
# *   Remove rows with `nan`
# *   Fill values to `nan`

# %%
dfr.dropna()
# Out:
#         first_name last_name   age  gender    race death_date  \
# 0         Cesar A.   Aguilar  18.0    Male  Latino 1992-04-30
# 1           George   Alvarez  42.0    Male  Latino 1992-05-01
# 2           Wilson   Alvarez  40.0    Male  Latino 1992-05-23
# 3         Brian E.    Andrew  30.0    Male   Black 1992-04-30
# 4           Vivian    Austin  87.0  Female   Black 1992-05-03
# ..             ...       ...   ...     ...     ...        ...
# 58        Fredrick      Ward  20.0    Male   Black 1992-05-02
# 59        Louis A.    Watson  18.0    Male   Black 1992-04-29
# 60       Elbert O.   Wilkins  33.0    Male   Black 1992-04-30
# 61         John H.   Willers  37.0    Male   White 1992-04-29
# 62  Willie Bernard  Williams  29.0    Male   Black 1992-04-29
#
#                          address         neighborhood  \
# 0                2009 W. 6th St.             Westlake
# 1         Main & College streets            Chinatown
# 2            3100 Rosecrans Ave.            Hawthorne
# 3    Rosecrans & Chester avenues              Compton
# 4               1600 W. 60th St.         Harvard Park
# ..                           ...                  ...
# 58             11932 Cometa Ave.              Pacoima
# 59          4365 S. Vermont Ave.       Vermont Square
# 60  Western Avenue & 92nd Street        Gramercy Park
# 61         10621 Sepulveda Blvd.        Mission Hills
# 62        Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude
# 0   Officer-involved shooting -118.273976  34.059281
# 1            Not riot-related -118.234098  34.062690
# 2                    Homicide -118.326816  33.901662
# 3   Officer-involved shooting -118.215390  33.903457
# 4                       Death -118.304741  33.985667
# ..                        ...         ...        ...
# 58                   Homicide -118.412778  34.287098
# 59                   Homicide -118.291557  34.005244
# 60                   Homicide -118.310004  33.952767
# 61                   Homicide -118.467770  34.263184
# 62                      Death -118.308952  33.982363
#
# [62 rows x 11 columns]

# %% [markdown]
# And this is the function to give values to `nan`.

# %%
dfr[dfr.age.isna()]
# Out:
#    first_name last_name  age gender   race death_date  \
# 11       John   Doe #80  NaN   Male  White 1992-05-02
#
#                                address     neighborhood      type   longitude  \
# 11  5800 block of South Vermont Avenue  Vermont-Slauson  Homicide -118.291495
#
#      latitude
# 11  33.989399

# %%
dfr.fillna(value=80)
# Out:
#         first_name last_name   age  gender    race death_date  \
# 0         Cesar A.   Aguilar  18.0    Male  Latino 1992-04-30
# 1           George   Alvarez  42.0    Male  Latino 1992-05-01
# 2           Wilson   Alvarez  40.0    Male  Latino 1992-05-23
# 3         Brian E.    Andrew  30.0    Male   Black 1992-04-30
# 4           Vivian    Austin  87.0  Female   Black 1992-05-03
# ..             ...       ...   ...     ...     ...        ...
# 58        Fredrick      Ward  20.0    Male   Black 1992-05-02
# 59        Louis A.    Watson  18.0    Male   Black 1992-04-29
# 60       Elbert O.   Wilkins  33.0    Male   Black 1992-04-30
# 61         John H.   Willers  37.0    Male   White 1992-04-29
# 62  Willie Bernard  Williams  29.0    Male   Black 1992-04-29
#
#                          address         neighborhood  \
# 0                2009 W. 6th St.             Westlake
# 1         Main & College streets            Chinatown
# 2            3100 Rosecrans Ave.            Hawthorne
# 3    Rosecrans & Chester avenues              Compton
# 4               1600 W. 60th St.         Harvard Park
# ..                           ...                  ...
# 58             11932 Cometa Ave.              Pacoima
# 59          4365 S. Vermont Ave.       Vermont Square
# 60  Western Avenue & 92nd Street        Gramercy Park
# 61         10621 Sepulveda Blvd.        Mission Hills
# 62        Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude
# 0   Officer-involved shooting -118.273976  34.059281
# 1            Not riot-related -118.234098  34.062690
# 2                    Homicide -118.326816  33.901662
# 3   Officer-involved shooting -118.215390  33.903457
# 4                       Death -118.304741  33.985667
# ..                        ...         ...        ...
# 58                   Homicide -118.412778  34.287098
# 59                   Homicide -118.291557  34.005244
# 60                   Homicide -118.310004  33.952767
# 61                   Homicide -118.467770  34.263184
# 62                      Death -118.308952  33.982363
#
# [63 rows x 11 columns]

# %% [markdown]
# ## Exercise
#
# In the dataframe `dfc`, drop the rows with a missing `Horsepower` value and assign the median value of the column to the missing values in `Miles_per_Gallon`.

# %%
dfc_cleaned = dfc.dropna(subset=['Horsepower'])

median_mpg = dfc_cleaned['Miles_per_Gallon'].median()
dfc_cleaned['Miles_per_Gallon'].fillna(median_mpg, inplace=True)

dfc_cleaned
# Out:
# <ipython-input-77-02177cdf4e2f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc_cleaned['Miles_per_Gallon'].fillna(median_mpg, inplace=True)
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 0         130.0           3504          12.0 1970-01-01     USA
# 1         165.0           3693          11.5 1970-01-01     USA
# 2         150.0           3436          11.0 1970-01-01     USA
# 3         150.0           3433          12.0 1970-01-01     USA
# 4         140.0           3449          10.5 1970-01-01     USA
# ..          ...            ...           ...        ...     ...
# 401        86.0           2790          15.6 1982-01-01     USA
# 402        52.0           2130          24.6 1982-01-01  Europe
# 403        84.0           2295          11.6 1982-01-01     USA
# 404        79.0           2625          18.6 1982-01-01     USA
# 405        82.0           2720          19.4 1982-01-01     USA
#
# [400 rows x 9 columns]

# %% [markdown]
# ## Exercise
#
# Write the code to view all the rows in a dataframe that contains a `nan` value. It should work for any dataframe.

# %%
dfr[dfr.isna()]
# Out:
#    first_name last_name  age gender race death_date address neighborhood type  \
# 0         NaN       NaN  NaN    NaN  NaN        NaT     NaN          NaN  NaN
# 1         NaN       NaN  NaN    NaN  NaN        NaT     NaN          NaN  NaN
# 2         NaN       NaN  NaN    NaN  NaN        NaT     NaN          NaN  NaN
# 3         NaN       NaN  NaN    NaN  NaN        NaT     NaN          NaN  NaN
# 4         NaN       NaN  NaN    NaN  NaN        NaT     NaN          NaN  NaN
# ..        ...       ...  ...    ...  ...        ...     ...          ...  ...
# 58        NaN       NaN  NaN    NaN  NaN        NaT     NaN          NaN  NaN
# 59        NaN       NaN  NaN    NaN  NaN        NaT     NaN          NaN  NaN
# 60        NaN       NaN  NaN    NaN  NaN        NaT     NaN          NaN  NaN
# 61        NaN       NaN  NaN    NaN  NaN        NaT     NaN          NaN  NaN
# 62        NaN       NaN  NaN    NaN  NaN        NaT     NaN          NaN  NaN
#
#     longitude  latitude
# 0         NaN       NaN
# 1         NaN       NaN
# 2         NaN       NaN
# 3         NaN       NaN
# 4         NaN       NaN
# ..        ...       ...
# 58        NaN       NaN
# 59        NaN       NaN
# 60        NaN       NaN
# 61        NaN       NaN
# 62        NaN       NaN
#
# [63 rows x 11 columns]

# %% [markdown]
# # Query
#
# There is an useful and powerful way to select rows from a DataFrame that meet certain criteria. The `query` method allows to write complex Boolean expressions that can be evaluated against each row of the DataFrame.
#
# Let's consider the car dataframe `dfc`.

# %%
dfc = data.cars()
dfc
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 0         130.0           3504          12.0 1970-01-01     USA
# 1         165.0           3693          11.5 1970-01-01     USA
# 2         150.0           3436          11.0 1970-01-01     USA
# 3         150.0           3433          12.0 1970-01-01     USA
# 4         140.0           3449          10.5 1970-01-01     USA
# ..          ...            ...           ...        ...     ...
# 401        86.0           2790          15.6 1982-01-01     USA
# 402        52.0           2130          24.6 1982-01-01  Europe
# 403        84.0           2295          11.6 1982-01-01     USA
# 404        79.0           2625          18.6 1982-01-01     USA
# 405        82.0           2720          19.4 1982-01-01     USA
#
# [406 rows x 9 columns]

# %% [markdown]
# We can select rows considering a condition on a column

# %%
dfc.query('Cylinders == 4')
# Out:
#                              Name  Miles_per_Gallon  Cylinders  Displacement  \
# 10           citroen ds-21 pallas               NaN          4         133.0
# 20          toyota corona mark ii              24.0          4         113.0
# 24                   datsun pl510              27.0          4          97.0
# 25   volkswagen 1131 deluxe sedan              26.0          4          97.0
# 26                    peugeot 504              25.0          4         110.0
# ..                            ...               ...        ...           ...
# 401               ford mustang gl              27.0          4         140.0
# 402                     vw pickup              44.0          4          97.0
# 403                 dodge rampage              32.0          4         135.0
# 404                   ford ranger              28.0          4         120.0
# 405                    chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 10        115.0           3090          17.5 1970-01-01  Europe
# 20         95.0           2372          15.0 1970-01-01   Japan
# 24         88.0           2130          14.5 1970-01-01   Japan
# 25         46.0           1835          20.5 1970-01-01  Europe
# 26         87.0           2672          17.5 1970-01-01  Europe
# ..          ...            ...           ...        ...     ...
# 401        86.0           2790          15.6 1982-01-01     USA
# 402        52.0           2130          24.6 1982-01-01  Europe
# 403        84.0           2295          11.6 1982-01-01     USA
# 404        79.0           2625          18.6 1982-01-01     USA
# 405        82.0           2720          19.4 1982-01-01     USA
#
# [207 rows x 9 columns]

# %% [markdown]
# Or, condition involving several columns

# %%
dfc.query('Cylinders==4 & Miles_per_Gallon < 20')
# Out:
#                 Name  Miles_per_Gallon  Cylinders  Displacement  Horsepower  \
# 83   volvo 145e (sw)              18.0          4         121.0       112.0
# 119       ford pinto              19.0          4         122.0        85.0
# 127      volvo 144ea              19.0          4         121.0       112.0
# 216      peugeot 504              19.0          4         120.0        88.0
#
#      Weight_in_lbs  Acceleration       Year  Origin
# 83            2933          14.5 1972-01-01  Europe
# 119           2310          18.5 1973-01-01     USA
# 127           2868          15.5 1973-01-01  Europe
# 216           3270          21.9 1976-01-01  Europe

# %%
dfc.query('(Cylinders==4 | Cylinders==6) & Miles_per_Gallon < 20')

# %% [markdown]
# But the most interesting feature is that we can compare values in different columns:

# %%
dfc.query('Displacement > Horsepower')

# %% [markdown]
# And use expressions!

# %%
dfc.query('Displacement > Horsepower * 3')
# Out:
#                                   Name  Miles_per_Gallon  Cylinders  \
# 161                    mercury monarch              15.0          6
# 162                      ford maverick              15.0          6
# 207                  ford granada ghia              18.0          6
# 372              oldsmobile cutlass ls              26.6          8
# 395  oldsmobile cutlass ciera (diesel)              38.0          6
#
#      Displacement  Horsepower  Weight_in_lbs  Acceleration       Year Origin
# 161         250.0        72.0           3432          21.0 1975-01-01    USA
# 162         250.0        72.0           3158          19.5 1975-01-01    USA
# 207         250.0        78.0           3574          21.0 1976-01-01    USA
# 372         350.0       105.0           3725          19.0 1982-01-01    USA
# 395         262.0        85.0           3015          17.0 1982-01-01    USA

# %% [markdown]
# ## **Exercise**

# %% [markdown]
# In the dataframe `dfr`, select the rows whose `age` is over 30, `neiborhood` contains `Park` and `gender` is `Female`:

# %%
dfr.query("age > 30 and neighborhood.str.contains('Park') and gender == 'Female'")
# Out:
#    first_name last_name   age  gender   race death_date  \
# 4      Vivian    Austin  87.0  Female  Black 1992-05-03
# 6       Carol    Benson  42.0  Female  Black 1992-05-02
# 26      Betty   Jackson  56.0  Female  Black 1992-05-01
#
#                                address  neighborhood   type   longitude  \
# 4                     1600 W. 60th St.  Harvard Park  Death -118.304741
# 6   Harbor Freeway near Slauson Avenue    South Park  Death -118.280504
# 26                 Main & 51st streets    South Park  Death -118.273931
#
#      latitude
# 4   33.985667
# 6   33.989168
# 26  33.996522

# %% [markdown]
# ## **Exercise**
#
# In the dataframe `dfc` select the Volkswagen cars with a weight of more than 20 kilograms per horsepower.

# %%
dfc.query(" Name.str.contains('Volkswagen') & (Weight_in_lbs/2.5)/Horsepower>20")
# Out:
# Empty DataFrame
# Columns: [Name, Miles_per_Gallon, Cylinders, Displacement, Horsepower, Weight_in_lbs, Acceleration, Year, Origin]
# Index: []

# %% [markdown]
# <hr>
# <hr>
# Carlos Gregorio Rodríguez
#
# Universidad Complutense de Madrid
#
# <img src="https://static0.makeuseofimages.com/wordpress/wp-content/uploads/2019/11/CC-BY-NC-License.png" alt="cc by nc" width="200"/>
#
#
# https://creativecommons.org/licenses/by-nc/4.0/
