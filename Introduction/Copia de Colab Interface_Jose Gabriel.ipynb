# %% [markdown]
# This is the copy of the file of Jose

# %% [markdown]
# #Notebooks

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# When I share a notebook with you, you have your own personal copy of the document. Experiment with it and try new things as much as you want, you will not spoil the original. Every time you follow the provided link you will get a fresh new copy.
#
# A few cells below you will learn how to save your personal copy of this notebook, if you are interested in keeping the changes you made to it.

# %% [markdown]
# # Interactive Cells

# %% [markdown]
# The key element of the notebooks are the cells. A notebook is formed by cells.
#
# There are two types of cells:
#
# * Text cells
# * Code cells
#
# With a single click you select a text cell and see its boundaries.
#
# With a double click you edit a text cell...

# %% [markdown]
# In a code cell we introduce code and execute with the play icon on the left

# %%
import pandas as pd
pd.__version__

# %% [markdown]
# ## New cells

# %% [markdown]
# some more text!

# %% [markdown]
# To add new cells the easiest way is to move the pointer between two cells.

# %%
print('Hello!')

# %% [markdown]
# ## The cell menu

# %% [markdown]
# Some basic operations on cells can be done using the menu on the upper right corner of every cell.

# %% [markdown]
# # `Google Colab` Interface

# %% [markdown]
# There are three main components in the interface
#
# * The notebook on the right
# * The menu bar on the top
# * The tab column on the left

# %% [markdown]
# ## Top Menu

# %% [markdown]
#    ![menu.jpeg](data:image/jpeg;base64,...)
#
# This menu has the typical possibilities to edit documents: save, cut, copy, find... but also some other related to the notebook code cells and the runtime that execute the computations.
#
# For instance, you can click on "Save a copy in Drive" if you are intereted in keeping this notebook.

# %% [markdown]
# ## Left Tab

# %% [markdown]
# In the tab on the left we find information on the context of the notebook. For instance:
#
# * ![tab1.jpeg](data:image/jpeg;base64,...)
# The first one shows the table of contents and allow a quick navigation through the document.
#
# * ![tab2.jpeg](data:image/jpeg;base64,...)The last one shows the files the notebook can use.

# %% [markdown]
# # `Colab Notebooks` folder in `Drive`

# %% [markdown]
# When you start using `Colab`, a new folder is created in your Drive called `Colab Notebooks`.
#
# Have a look at your `Drive`.

# %% [markdown]
# # Data Files

# %% [markdown]
# Ultimately data are stored in files, so it's very important to grasp how to use files in `Colab`.

# %% [markdown]
# ## Folder `sample data`

# %% [markdown]
# Every notebook has an small folder with a few datasets. To use this files we have to correctly write its path.

# %%
import pandas as pd
pd.read_csv('/content/sample_data/california_housing_test.csv')

# %% [markdown]
# ## Uploaded files

# %% [markdown]
# It is possible to upload files to the folders of the notebook. But we have to know that all data will be wiped out the moment we stop working with the notebook and the runtime is disconnected. (Probably a warning will inform you.)
#
# Let's upload a file and use it in an example cell code.

# %%
import pandas as pd
pd.read_json('/content/sample_data/colors.json')

# %% [markdown]
# ## Personal files in `Drive`

# %% [markdown]
# But we can also make use of the files we already have in `Google Drive`.
# For that, we have to **mount** the `Drive`.
#
# There are different ways to do it, maybe the simplest one is to go to the folder tab on the left and click on the icon
# ![image.png](data:image/png;base64,...)
#
#
# You will have to confirm that you want the notebook to get access to your `Drive`. Remember that the notebook is yours.

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# Finally, in the folder tab on the left you can see the `drive` folder. Files can be moved back and forth from `Drive` and `sample data`

# %% [markdown]
# ## Downloaded files

# %% [markdown]
# Files can also be downloaded from the internet to the environment of the notebook.
#
# Imagine that you want to work with some data that are accesible on-line,for instance
#
# https://opendata.ecdc.europa.eu/covid19/testing/csv/data.csv

# %% [markdown]
# And it's good to know that we could put those data in our `Colab`file system by using a code cell.
#
# For instance, we could use this command:

# %%
# !wget https://opendata.ecdc.europa.eu/covid19/testing/csv/data.csv

# %% [markdown]
# Yes, in the code cells not only `python` code can be executed. We already see how to use `html` code and in this previous cell code we are using linux terminal commands. That brings a lot of possibilities... just in case you want to explore a bit more https://linuxconfig.org/linux-commands-cheat-sheet

# %% [markdown]
# Notice that we could also use `python` code or other other alternative commands to download files.

# %% [markdown]
# # Share your Notebooks

# %% [markdown]
# Finally, let's see how the notebooks can be shared.
#
# If you are editig the notebook on `Colab`, on the top right corner there is a `Share` icon. Once you click it, you can choose the who you share the document with and the privileges to access the notebook.
#
# This is exactly the same procedure as for sharing folders and files in `Drive`.

# %% [markdown]
# <hr><hr>
#
# Carlos Gregorio Rodríguez
#
# Universidad Complutense de Madrid
#
# <img src="https://static0.makeuseofimages.com/wordpress/wp-content/uploads/2019/11/CC-BY-NC-License.png" alt="cc by nc" width="200"/>
#
# https://creativecommons.org/licenses/by-nc/4.0/
