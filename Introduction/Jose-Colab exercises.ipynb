# %% [markdown]
# # Exercise: Access to files in `Drive`
#
# First of all, connect your notebook with `Drive`.
#
# You can check if the connection is established by executing the following cell code.
#
# In case of problems you can always check again the notebook where we explained how to do it.

# %%
#@title **Self evaluation**: Access to files in Drive {display-mode: "form"}

import os
try:
  drive = os.listdir("/content/drive")
  print("GOOD!!!, Drive unit is integrated in the notebok")
except FileNotFoundError as e:
  print("Drive unit is not ready.\n Use the folder icon on the left tab...")
# Out:
# GOOD!!!, Drive unit is integrated in the notebok

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Exercise**: Create a folder `data` in `Drive`
#
# Create a subfolder named `data` inside the `Colab Notebooks` folder in your `Drive` unit.

# %%
#@title **Self Evaluation**: Create a folder `data` in `Drive`

#@markdown Execute the cell to check if the folder is created.
try:
 import os
 if "data" in os.listdir("/content/drive/MyDrive/Colab Notebooks"):
  print("GOOD!!!, the subfolder data it is in Colab Notebook in Drive")
 else:
  print("There is not folder 'data'. Check the name...\n")
except:
   print('It is essential first to connect the Drive, move to the previous exercise')
# Out:
# GOOD!!!, the subfolder data it is in Colab Notebook in Drive

# %% [markdown]
# # **Exercise**: Download a `CSV` file

# %% [markdown]
# Download the file [Seattle meteorological data](https://drive.google.com/file/d/1NsbALAWEqxvg_Jhe88nHp4eyvvGIZSs_/view?usp=sharing) with your browser and uploaded it to the folder `data` you just create in the previous exercise. Beware of preserve exactly the name of the file: `seattle_weather.csv`.

# %%
#@title **Self Evaluation**: Download a `CSV` file

#@markdown Put the downloaded file in the `data` folder and execute this cell.

import os
try:
 if "seattle_weather.csv" in os.listdir("/content/drive/MyDrive/Colab Notebooks/data"):
  print("GOOD!!!, file 'seattle_weather.csv' is in the 'data' folder")
 else:
  print("The file is not in the 'data' folder")
  print("Check again, please and rerun the cell")
except:
  print('It is essential first to complete the previous exercises')
# Out:
# GOOD!!!, file 'seattle_weather.csv' is in the 'data' folder

# %% [markdown]
# By running the next code cell we can see the fist 10 lines of the file.

# %% [markdown]
# !head -10 "/content/drive/MyDrive/Colab Notebooks/data/seattle_weather.csv"

# %%
# !head -10 "/content/drive/MyDrive/Colab Notebooks/data/seattle_weather.csv"
# Out:
# id,date,precipitation,temp_max,temp_min,wind,weather
# 0,2012-01-01,0.0,12.8,5.0,4.7,drizzle
# 1,2012-01-02,10.9,10.6,2.8,4.5,rain
# 2,2012-01-03,0.8,11.7,7.2,2.3,rain
# 3,2012-01-04,20.3,12.2,5.6,4.7,rain
# 4,2012-01-05,1.3,8.9,2.8,6.1,rain
# 5,2012-01-06,2.5,4.4,2.2,2.2,rain
# 6,2012-01-07,0.0,7.2,2.8,2.3,rain
# 7,2012-01-08,0.0,10.0,2.8,2.0,sun
# 8,2012-01-09,4.3,9.4,5.0,3.4,rain

# %% [markdown]
# # **Exercise**: Download a `JSON` file
#
# Download the data file [Nueva York bicycles](https://drive.google.com/file/d/10SnjVuXrOQW84puVNnIgVjuQnHNkZ-BJ/view). Uploaded to the 'data' folder as in the previous exercise. Beware of preserve the name `trips.json`.

# %%
#@title **Self Evaluation**: Download a `JSON` file

#@markdown Put the downloaded file in the 'data' folder and execute this cell.

try:
 if "trips.json" in os.listdir("/content/drive/MyDrive/Colab Notebooks/data"):
  print("GOOD!!!, the file 'trips.json' is in the 'data' folder")
 else:
  print("The file is not in the 'data' folder")
  print("Check again, please and rerun the cell")
except:
  print('It is essential first to complete the previous exercises')
# Out:
# GOOD!!!, the file 'trips.json' is in the 'data' folder

# %% [markdown]
# # **Exercise**: Publish the notebook
#
# In this exercise we will ask you to publish your own copy of this notebook.
#
# Change the title and add your name to it.
# Make the notebook accessible to anyone with the link.

# %% [markdown]
# <hr><hr>
#
# Carlos Gregorio Rodríguez
#
# Universidad Complutense de Madrid
#
# <img src="https://static0.makeuseofimages.com/wordpress/wp-content/uploads/2019/11/CC-BY-NC-License.png" alt="cc by nc" width="200"/>
#
#
# https://creativecommons.org/licenses/by-nc/4.0/
