# %% [markdown]
#  <img src="https://upload.wikimedia.org/wikipedia/commons/e/ed/Pandas_logo.svg" alt="Panda Logo" width="500">
#
# `Pandas` is a `Python` module for data manipulation and analysis widely used all around the world both in universities and companies. We will show how easy is to work with data in notebooks using a few lines of `Pandas` code.
#
# https://pandas.pydata.org/

# %%
# %reload_ext google.colab.data_table
import pandas as pd
from vega_datasets import data

# %% [markdown]
# # New columns
#
# There are occasions when we want to combine the information in a dataframe in order to generate new columns.
#
# Let's consider the dataframe `dfr`

# %%
dfr = data.la_riots()
dfr.sample(20)
# Out:
#         first_name      last_name   age  gender    race death_date  \
# 19           Elias  Garcia Rivera  32.0    Male  Latino 1992-12-16
# 14          Howard        Epstein  45.0    Male   White 1992-04-30
# 20         Andreas        Garnica  36.0    Male  Latino 1992-04-30
# 12           Harry         Doller  56.0    Male   White 1992-05-01
# 45           Aaron       Ratinoff  68.0    Male   White 1992-05-01
# 49            Imad         Sharaf  31.0    Male   Black 1992-05-03
# 3         Brian E.         Andrew  30.0    Male   Black 1992-04-30
# 2           Wilson        Alvarez  40.0    Male  Latino 1992-05-23
# 26           Betty        Jackson  56.0  Female   Black 1992-05-01
# 44         Hugo G.        Ramirez  23.0    Male  Latino 1992-05-03
# 13        Kevin J.        Edwards  35.0    Male   Black 1992-04-30
# 29     Edward Song            Lee  18.0    Male   Asian 1992-04-30
# 61         John H.        Willers  37.0    Male   White 1992-04-29
# 30        Frank D.          Lopez  36.0    Male  Latino 1992-04-30
# 10         Gregory      Davis Jr.  15.0    Male   Black 1992-04-30
# 15           Juana       Espinosa  65.0  Female  Latino 1992-05-02
# 60       Elbert O.        Wilkins  33.0    Male   Black 1992-04-30
# 56  Edward Anthony        Travens  15.0    Male   White 1992-04-29
# 23          Jimmie         Harris  38.0    Male   Black 1992-04-29
# 36       Arturo C.        Miranda  23.0    Male  Latino 1992-04-29
#
#                                               address    neighborhood  \
# 19                                  12834 Vanowen St.     Valley Glen
# 14                              Slauson & 7th avenues       Hyde Park
# 20                                 2034 W. Pico Blvd.      Pico-Union
# 12                        3500 block of Winslow Drive     Silver Lake
# 45                                11690 Gateway Blvd.        Sawtelle
# 49  San Diego Freeway & San Fernando Mission Boule...   Mission Hills
# 3                         Rosecrans & Chester avenues         Compton
# 2                                 3100 Rosecrans Ave.       Hawthorne
# 26                                Main & 51st streets      South Park
# 44                                     12732 Bess St.    Baldwin Park
# 13                                 614 S. Locust Ave.         Compton
# 29                      Hobart Boulevard & 3rd Street       Koreatown
# 61                              10621 Sepulveda Blvd.   Mission Hills
# 30                       16th Street & Central Avenue        Downtown
# 10                       Vermont Avenue & 43rd Street  Vermont Square
# 15                               7608 S. Compton Ave.         Compton
# 60                       Western Avenue & 92nd Street   Gramercy Park
# 56  San Fernando Road & San Fernando Mission Boule...    San Fernando
# 23                  Avalon Boulevard & Slauson Avenue      South Park
# 36                      120th Street & Central Avenue   Green Meadows
#
#                          type   longitude   latitude
# 19                   Homicide -118.413791  34.193934
# 14                   Homicide -118.324742  33.989049
# 20           Not riot-related -118.281879  34.046844
# 12           Not riot-related -118.278763  34.087788
# 45                   Homicide -118.443100  34.028655
# 49           Not riot-related -118.471745  34.271856
# 3   Officer-involved shooting -118.215390  33.903457
# 2                    Homicide -118.326816  33.901662
# 26                      Death -118.273931  33.996522
# 44           Not riot-related -117.997106  34.070238
# 13           Not riot-related -118.200252  33.892421
# 29                   Homicide -118.305439  34.068985
# 61                   Homicide -118.467770  34.263184
# 30                   Homicide -118.248765  34.026427
# 10                   Homicide -118.291549  34.005485
# 15                   Homicide -118.246188  33.919821
# 60                   Homicide -118.310004  33.952767
# 56           Not riot-related -118.443003  34.284187
# 23                      Death -118.265199  33.989245
# 36                   Homicide -118.254343  33.923730

# %% [markdown]
# ## Column operators

# %% [markdown]
# Let's merge, for instance, the `first_name` and `last_name` columns. As it is usual, we can add a comma ',' to separate the last name from the first name. The combined data will be placed in a new column that we will call just `name`.

# %%
dfr['name'] = dfr.last_name+', '+dfr.first_name
dfr
# Out:
#         first_name last_name   age  gender    race death_date  \
# 0         Cesar A.   Aguilar  18.0    Male  Latino 1992-04-30
# 1           George   Alvarez  42.0    Male  Latino 1992-05-01
# 2           Wilson   Alvarez  40.0    Male  Latino 1992-05-23
# 3         Brian E.    Andrew  30.0    Male   Black 1992-04-30
# 4           Vivian    Austin  87.0  Female   Black 1992-05-03
# ..             ...       ...   ...     ...     ...        ...
# 58        Fredrick      Ward  20.0    Male   Black 1992-05-02
# 59        Louis A.    Watson  18.0    Male   Black 1992-04-29
# 60       Elbert O.   Wilkins  33.0    Male   Black 1992-04-30
# 61         John H.   Willers  37.0    Male   White 1992-04-29
# 62  Willie Bernard  Williams  29.0    Male   Black 1992-04-29
#
#                          address         neighborhood  \
# 0                2009 W. 6th St.             Westlake
# 1         Main & College streets            Chinatown
# 2            3100 Rosecrans Ave.            Hawthorne
# 3    Rosecrans & Chester avenues              Compton
# 4               1600 W. 60th St.         Harvard Park
# ..                           ...                  ...
# 58             11932 Cometa Ave.              Pacoima
# 59          4365 S. Vermont Ave.       Vermont Square
# 60  Western Avenue & 92nd Street        Gramercy Park
# 61         10621 Sepulveda Blvd.        Mission Hills
# 62        Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude                      name
# 0   Officer-involved shooting -118.273976  34.059281         Aguilar, Cesar A.
# 1            Not riot-related -118.234098  34.062690           Alvarez, George
# 2                    Homicide -118.326816  33.901662           Alvarez, Wilson
# 3   Officer-involved shooting -118.215390  33.903457          Andrew, Brian E.
# 4                       Death -118.304741  33.985667            Austin, Vivian
# ..                        ...         ...        ...                       ...
# 58                   Homicide -118.412778  34.287098            Ward, Fredrick
# 59                   Homicide -118.291557  34.005244          Watson, Louis A.
# 60                   Homicide -118.310004  33.952767        Wilkins, Elbert O.
# 61                   Homicide -118.467770  34.263184          Willers, John H.
# 62                      Death -118.308952  33.982363  Williams, Willie Bernard
#
# [63 rows x 12 columns]

# %% [markdown]
# If we want to get rid of the original columns, we can use the `drop` method.

# %%
dfr.drop(columns=['first_name', 'last_name'], inplace=True)
dfr
# Out:
#      age  gender    race death_date                       address  \
# 0   18.0    Male  Latino 1992-04-30               2009 W. 6th St.
# 1   42.0    Male  Latino 1992-05-01        Main & College streets
# 2   40.0    Male  Latino 1992-05-23           3100 Rosecrans Ave.
# 3   30.0    Male   Black 1992-04-30   Rosecrans & Chester avenues
# 4   87.0  Female   Black 1992-05-03              1600 W. 60th St.
# ..   ...     ...     ...        ...                           ...
# 58  20.0    Male   Black 1992-05-02             11932 Cometa Ave.
# 59  18.0    Male   Black 1992-04-29          4365 S. Vermont Ave.
# 60  33.0    Male   Black 1992-04-30  Western Avenue & 92nd Street
# 61  37.0    Male   White 1992-04-29         10621 Sepulveda Blvd.
# 62  29.0    Male   Black 1992-04-29        Gage & Western avenues
#
#            neighborhood                       type   longitude   latitude  \
# 0              Westlake  Officer-involved shooting -118.273976  34.059281
# 1             Chinatown           Not riot-related -118.234098  34.062690
# 2             Hawthorne                   Homicide -118.326816  33.901662
# 3               Compton  Officer-involved shooting -118.215390  33.903457
# 4          Harvard Park                      Death -118.304741  33.985667
# ..                  ...                        ...         ...        ...
# 58              Pacoima                   Homicide -118.412778  34.287098
# 59       Vermont Square                   Homicide -118.291557  34.005244
# 60        Gramercy Park                   Homicide -118.310004  33.952767
# 61        Mission Hills                   Homicide -118.467770  34.263184
# 62  Chesterfield Square                      Death -118.308952  33.982363
#
#                         name
# 0          Aguilar, Cesar A.
# 1            Alvarez, George
# 2            Alvarez, Wilson
# 3           Andrew, Brian E.
# 4             Austin, Vivian
# ..                       ...
# 58            Ward, Fredrick
# 59          Watson, Louis A.
# 60        Wilkins, Elbert O.
# 61          Willers, John H.
# 62  Williams, Willie Bernard
#
# [63 rows x 10 columns]

# %% [markdown]
# The position in which to add a new column can be choosen.
# Notice that this operation transform the original dataframe.

# %%
dfr = data.la_riots()
dfr.insert(loc=2, column='name', value=dfr.last_name+', '+dfr.first_name)
dfr
# Out:
#         first_name last_name                      name   age  gender    race  \
# 0         Cesar A.   Aguilar         Aguilar, Cesar A.  18.0    Male  Latino
# 1           George   Alvarez           Alvarez, George  42.0    Male  Latino
# 2           Wilson   Alvarez           Alvarez, Wilson  40.0    Male  Latino
# 3         Brian E.    Andrew          Andrew, Brian E.  30.0    Male   Black
# 4           Vivian    Austin            Austin, Vivian  87.0  Female   Black
# ..             ...       ...                       ...   ...     ...     ...
# 58        Fredrick      Ward            Ward, Fredrick  20.0    Male   Black
# 59        Louis A.    Watson          Watson, Louis A.  18.0    Male   Black
# 60       Elbert O.   Wilkins        Wilkins, Elbert O.  33.0    Male   Black
# 61         John H.   Willers          Willers, John H.  37.0    Male   White
# 62  Willie Bernard  Williams  Williams, Willie Bernard  29.0    Male   Black
#
#    death_date                       address         neighborhood  \
# 0  1992-04-30               2009 W. 6th St.             Westlake
# 1  1992-05-01        Main & College streets            Chinatown
# 2  1992-05-23           3100 Rosecrans Ave.            Hawthorne
# 3  1992-04-30   Rosecrans & Chester avenues              Compton
# 4  1992-05-03              1600 W. 60th St.         Harvard Park
# ..        ...                           ...                  ...
# 58 1992-05-02             11932 Cometa Ave.              Pacoima
# 59 1992-04-29          4365 S. Vermont Ave.       Vermont Square
# 60 1992-04-30  Western Avenue & 92nd Street        Gramercy Park
# 61 1992-04-29         10621 Sepulveda Blvd.        Mission Hills
# 62 1992-04-29        Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude
# 0   Officer-involved shooting -118.273976  34.059281
# 1            Not riot-related -118.234098  34.062690
# 2                    Homicide -118.326816  33.901662
# 3   Officer-involved shooting -118.215390  33.903457
# 4                       Death -118.304741  33.985667
# ..                        ...         ...        ...
# 58                   Homicide -118.412778  34.287098
# 59                   Homicide -118.291557  34.005244
# 60                   Homicide -118.310004  33.952767
# 61                   Homicide -118.467770  34.263184
# 62                      Death -118.308952  33.982363
#
# [63 rows x 12 columns]

# %% [markdown]
# ### **Exercise**
#
# Add a new column with a boolean value indicating if the address is a crossroads.

# %%
dfr['cross'] = [1 if '&' in a else 0 for a in dfr['address']]

dfr
# Out:
#         first_name last_name                      name   age  gender    race  \
# 0         Cesar A.   Aguilar         Aguilar, Cesar A.  18.0    Male  Latino
# 1           George   Alvarez           Alvarez, George  42.0    Male  Latino
# 2           Wilson   Alvarez           Alvarez, Wilson  40.0    Male  Latino
# 3         Brian E.    Andrew          Andrew, Brian E.  30.0    Male   Black
# 4           Vivian    Austin            Austin, Vivian  87.0  Female   Black
# ..             ...       ...                       ...   ...     ...     ...
# 58        Fredrick      Ward            Ward, Fredrick  20.0    Male   Black
# 59        Louis A.    Watson          Watson, Louis A.  18.0    Male   Black
# 60       Elbert O.   Wilkins        Wilkins, Elbert O.  33.0    Male   Black
# 61         John H.   Willers          Willers, John H.  37.0    Male   White
# 62  Willie Bernard  Williams  Williams, Willie Bernard  29.0    Male   Black
#
#    death_date                       address         neighborhood  \
# 0  1992-04-30               2009 W. 6th St.             Westlake
# 1  1992-05-01        Main & College streets            Chinatown
# 2  1992-05-23           3100 Rosecrans Ave.            Hawthorne
# 3  1992-04-30   Rosecrans & Chester avenues              Compton
# 4  1992-05-03              1600 W. 60th St.         Harvard Park
# ..        ...                           ...                  ...
# 58 1992-05-02             11932 Cometa Ave.              Pacoima
# 59 1992-04-29          4365 S. Vermont Ave.       Vermont Square
# 60 1992-04-30  Western Avenue & 92nd Street        Gramercy Park
# 61 1992-04-29         10621 Sepulveda Blvd.        Mission Hills
# 62 1992-04-29        Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude  cross
# 0   Officer-involved shooting -118.273976  34.059281      0
# 1            Not riot-related -118.234098  34.062690      1
# 2                    Homicide -118.326816  33.901662      0
# 3   Officer-involved shooting -118.215390  33.903457      1
# 4                       Death -118.304741  33.985667      0
# ..                        ...         ...        ...    ...
# 58                   Homicide -118.412778  34.287098      0
# 59                   Homicide -118.291557  34.005244      0
# 60                   Homicide -118.310004  33.952767      1
# 61                   Homicide -118.467770  34.263184      0
# 62                      Death -118.308952  33.982363      1
#
# [63 rows x 13 columns]

# %% [markdown]
# ## Python code

# %% [markdown]
# But the combination of data can be more complex.
# Imagine we want to create a new column with compound values from other columns.
#
# For instance, we would like to combine the information in `latitude` and `longitude` in just one column. Naive expressions, as the following one, do not work!

# %%
dfr['position'] = (dfr.longitude, dfr.latitude)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-69f4b1d44e40> in <cell line: 1>()
# ----> 1 dfr['position'] = (dfr.longitude, dfr.latitude)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3948         else:
#    3949             # set column
# -> 3950             self._set_item(key, value)
#    3951
#    3952     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4141         ensure homogeneity.
#    4142         """
# -> 4143         value = self._sanitize_column(value)
#    4144
#    4145         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4868
#    4869         if is_list_like(value):
# -> 4870             com.require_length_match(value, self.index)
#    4871         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4872
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     574     """
#     575     if len(data) != len(index):
# --> 576         raise ValueError(
#     577             "Length of values "
#     578             f"({len(data)}) "
#
# ValueError: Length of values (2) does not match length of index (63)

# %% [markdown]
# We need to combine the values and then generate the new column. There is a `python` predefined function that is useful for that: `zip`

# %%
zip([1,2,3],['a','b','c'])

# %% [markdown]
# As we have already encountered before (for instance with `range`), `zip` is an example of lazy function!

# %%
list(zip([1,2,3],['a','b','c']))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %% [markdown]
# We now have the tool to solve the question:

# %%
dfr['position'] = list(zip(dfr.longitude, dfr.latitude))
dfr
# Out:
#         first_name last_name                      name   age  gender    race  \
# 0         Cesar A.   Aguilar         Aguilar, Cesar A.  18.0    Male  Latino
# 1           George   Alvarez           Alvarez, George  42.0    Male  Latino
# 2           Wilson   Alvarez           Alvarez, Wilson  40.0    Male  Latino
# 3         Brian E.    Andrew          Andrew, Brian E.  30.0    Male   Black
# 4           Vivian    Austin            Austin, Vivian  87.0  Female   Black
# ..             ...       ...                       ...   ...     ...     ...
# 58        Fredrick      Ward            Ward, Fredrick  20.0    Male   Black
# 59        Louis A.    Watson          Watson, Louis A.  18.0    Male   Black
# 60       Elbert O.   Wilkins        Wilkins, Elbert O.  33.0    Male   Black
# 61         John H.   Willers          Willers, John H.  37.0    Male   White
# 62  Willie Bernard  Williams  Williams, Willie Bernard  29.0    Male   Black
#
#    death_date                       address         neighborhood  \
# 0  1992-04-30               2009 W. 6th St.             Westlake
# 1  1992-05-01        Main & College streets            Chinatown
# 2  1992-05-23           3100 Rosecrans Ave.            Hawthorne
# 3  1992-04-30   Rosecrans & Chester avenues              Compton
# 4  1992-05-03              1600 W. 60th St.         Harvard Park
# ..        ...                           ...                  ...
# 58 1992-05-02             11932 Cometa Ave.              Pacoima
# 59 1992-04-29          4365 S. Vermont Ave.       Vermont Square
# 60 1992-04-30  Western Avenue & 92nd Street        Gramercy Park
# 61 1992-04-29         10621 Sepulveda Blvd.        Mission Hills
# 62 1992-04-29        Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude  cross  \
# 0   Officer-involved shooting -118.273976  34.059281      0
# 1            Not riot-related -118.234098  34.062690      1
# 2                    Homicide -118.326816  33.901662      0
# 3   Officer-involved shooting -118.215390  33.903457      1
# 4                       Death -118.304741  33.985667      0
# ..                        ...         ...        ...    ...
# 58                   Homicide -118.412778  34.287098      0
# 59                   Homicide -118.291557  34.005244      0
# 60                   Homicide -118.310004  33.952767      1
# 61                   Homicide -118.467770  34.263184      0
# 62                      Death -118.308952  33.982363      1
#
#                        position
# 0    (-118.2739756, 34.0592814)
# 1    (-118.2340982, 34.0626901)
# 2      (-118.326816, 33.901662)
# 3    (-118.2153903, 33.9034569)
# 4      (-118.304741, 33.985667)
# ..                          ...
# 58     (-118.412778, 34.287098)
# 59  (-118.2915566, 34.00524354)
# 60  (-118.3100043, 33.95276731)
# 61      (-118.46777, 34.263184)
# 62   (-118.3089517, 33.9823625)
#
# [63 rows x 14 columns]

# %% [markdown]
# Finally, the most complex situation would be to generate values for a new column considering the some of data in the row and conditions or further processing. In this case, we could use a function to define the code to be executed.
#
# Let's consider the following code to create a new column, observe how we could use any value in the row and arbitrary complex `python` code to generate the result.

# %%
def my_f(any_row):
  if '&' in any_row['address']:
    return (any_row['address'].split('&'))
  else:
    return any_row['address']

#create new column 'Good' using the function above
dfr['new_address'] = dfr.apply(my_f, axis=1)
dfr
# Out:
#         first_name last_name                      name   age  gender    race  \
# 0         Cesar A.   Aguilar         Aguilar, Cesar A.  18.0    Male  Latino
# 1           George   Alvarez           Alvarez, George  42.0    Male  Latino
# 2           Wilson   Alvarez           Alvarez, Wilson  40.0    Male  Latino
# 3         Brian E.    Andrew          Andrew, Brian E.  30.0    Male   Black
# 4           Vivian    Austin            Austin, Vivian  87.0  Female   Black
# ..             ...       ...                       ...   ...     ...     ...
# 58        Fredrick      Ward            Ward, Fredrick  20.0    Male   Black
# 59        Louis A.    Watson          Watson, Louis A.  18.0    Male   Black
# 60       Elbert O.   Wilkins        Wilkins, Elbert O.  33.0    Male   Black
# 61         John H.   Willers          Willers, John H.  37.0    Male   White
# 62  Willie Bernard  Williams  Williams, Willie Bernard  29.0    Male   Black
#
#    death_date                       address         neighborhood  \
# 0  1992-04-30               2009 W. 6th St.             Westlake
# 1  1992-05-01        Main & College streets            Chinatown
# 2  1992-05-23           3100 Rosecrans Ave.            Hawthorne
# 3  1992-04-30   Rosecrans & Chester avenues              Compton
# 4  1992-05-03              1600 W. 60th St.         Harvard Park
# ..        ...                           ...                  ...
# 58 1992-05-02             11932 Cometa Ave.              Pacoima
# 59 1992-04-29          4365 S. Vermont Ave.       Vermont Square
# 60 1992-04-30  Western Avenue & 92nd Street        Gramercy Park
# 61 1992-04-29         10621 Sepulveda Blvd.        Mission Hills
# 62 1992-04-29        Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude  cross  \
# 0   Officer-involved shooting -118.273976  34.059281      0
# 1            Not riot-related -118.234098  34.062690      1
# 2                    Homicide -118.326816  33.901662      0
# 3   Officer-involved shooting -118.215390  33.903457      1
# 4                       Death -118.304741  33.985667      0
# ..                        ...         ...        ...    ...
# 58                   Homicide -118.412778  34.287098      0
# 59                   Homicide -118.291557  34.005244      0
# 60                   Homicide -118.310004  33.952767      1
# 61                   Homicide -118.467770  34.263184      0
# 62                      Death -118.308952  33.982363      1
#
#                        position                      new_address
# 0    (-118.2739756, 34.0592814)                  2009 W. 6th St.
# 1    (-118.2340982, 34.0626901)        [Main ,  College streets]
# 2      (-118.326816, 33.901662)              3100 Rosecrans Ave.
# 3    (-118.2153903, 33.9034569)   [Rosecrans ,  Chester avenues]
# 4      (-118.304741, 33.985667)                 1600 W. 60th St.
# ..                          ...                              ...
# 58     (-118.412778, 34.287098)                11932 Cometa Ave.
# 59  (-118.2915566, 34.00524354)             4365 S. Vermont Ave.
# 60  (-118.3100043, 33.95276731)  [Western Avenue ,  92nd Street]
# 61      (-118.46777, 34.263184)            10621 Sepulveda Blvd.
# 62   (-118.3089517, 33.9823625)        [Gage ,  Western avenues]
#
# [63 rows x 15 columns]

# %% [markdown]
# ### Exercise
#
# The previous code was intended for explaining the possibility of using a general `python` function. But, this particular problem could be solved without using an auxiliary function. Find a solution with pure `pandas`.

# %%
import pandas as pd

dfr['new_address'] = dfr['address'].str.split('&')

dfr
# Out:
#         first_name last_name                      name   age  gender    race  \
# 0         Cesar A.   Aguilar         Aguilar, Cesar A.  18.0    Male  Latino
# 1           George   Alvarez           Alvarez, George  42.0    Male  Latino
# 2           Wilson   Alvarez           Alvarez, Wilson  40.0    Male  Latino
# 3         Brian E.    Andrew          Andrew, Brian E.  30.0    Male   Black
# 4           Vivian    Austin            Austin, Vivian  87.0  Female   Black
# ..             ...       ...                       ...   ...     ...     ...
# 58        Fredrick      Ward            Ward, Fredrick  20.0    Male   Black
# 59        Louis A.    Watson          Watson, Louis A.  18.0    Male   Black
# 60       Elbert O.   Wilkins        Wilkins, Elbert O.  33.0    Male   Black
# 61         John H.   Willers          Willers, John H.  37.0    Male   White
# 62  Willie Bernard  Williams  Williams, Willie Bernard  29.0    Male   Black
#
#    death_date                       address         neighborhood  \
# 0  1992-04-30               2009 W. 6th St.             Westlake
# 1  1992-05-01        Main & College streets            Chinatown
# 2  1992-05-23           3100 Rosecrans Ave.            Hawthorne
# 3  1992-04-30   Rosecrans & Chester avenues              Compton
# 4  1992-05-03              1600 W. 60th St.         Harvard Park
# ..        ...                           ...                  ...
# 58 1992-05-02             11932 Cometa Ave.              Pacoima
# 59 1992-04-29          4365 S. Vermont Ave.       Vermont Square
# 60 1992-04-30  Western Avenue & 92nd Street        Gramercy Park
# 61 1992-04-29         10621 Sepulveda Blvd.        Mission Hills
# 62 1992-04-29        Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude  cross  \
# 0   Officer-involved shooting -118.273976  34.059281      0
# 1            Not riot-related -118.234098  34.062690      1
# 2                    Homicide -118.326816  33.901662      0
# 3   Officer-involved shooting -118.215390  33.903457      1
# 4                       Death -118.304741  33.985667      0
# ..                        ...         ...        ...    ...
# 58                   Homicide -118.412778  34.287098      0
# 59                   Homicide -118.291557  34.005244      0
# 60                   Homicide -118.310004  33.952767      1
# 61                   Homicide -118.467770  34.263184      0
# 62                      Death -118.308952  33.982363      1
#
#                        position                      new_address   old
# 0    (-118.2739756, 34.0592814)                [2009 W. 6th St.]  18.0
# 1    (-118.2340982, 34.0626901)        [Main ,  College streets]  47.0
# 2      (-118.326816, 33.901662)            [3100 Rosecrans Ave.]  45.0
# 3    (-118.2153903, 33.9034569)   [Rosecrans ,  Chester avenues]  30.0
# 4      (-118.304741, 33.985667)               [1600 W. 60th St.]  92.0
# ..                          ...                              ...   ...
# 58     (-118.412778, 34.287098)              [11932 Cometa Ave.]  20.0
# 59  (-118.2915566, 34.00524354)           [4365 S. Vermont Ave.]  18.0
# 60  (-118.3100043, 33.95276731)  [Western Avenue ,  92nd Street]  33.0
# 61      (-118.46777, 34.263184)          [10621 Sepulveda Blvd.]  42.0
# 62   (-118.3089517, 33.9823625)        [Gage ,  Western avenues]  29.0
#
# [63 rows x 16 columns]

# %% [markdown]
# ### Exercise
#
# Use the `apply` function to generate a new column using the information in each row.

# %%
dfr['old'] = dfr['age'].apply(lambda x: x+5 if x>35 else x)

dfr
# Out:
#         first_name last_name                      name   age  gender    race  \
# 0         Cesar A.   Aguilar         Aguilar, Cesar A.  18.0    Male  Latino
# 1           George   Alvarez           Alvarez, George  42.0    Male  Latino
# 2           Wilson   Alvarez           Alvarez, Wilson  40.0    Male  Latino
# 3         Brian E.    Andrew          Andrew, Brian E.  30.0    Male   Black
# 4           Vivian    Austin            Austin, Vivian  87.0  Female   Black
# ..             ...       ...                       ...   ...     ...     ...
# 58        Fredrick      Ward            Ward, Fredrick  20.0    Male   Black
# 59        Louis A.    Watson          Watson, Louis A.  18.0    Male   Black
# 60       Elbert O.   Wilkins        Wilkins, Elbert O.  33.0    Male   Black
# 61         John H.   Willers          Willers, John H.  37.0    Male   White
# 62  Willie Bernard  Williams  Williams, Willie Bernard  29.0    Male   Black
#
#    death_date                       address         neighborhood  \
# 0  1992-04-30               2009 W. 6th St.             Westlake
# 1  1992-05-01        Main & College streets            Chinatown
# 2  1992-05-23           3100 Rosecrans Ave.            Hawthorne
# 3  1992-04-30   Rosecrans & Chester avenues              Compton
# 4  1992-05-03              1600 W. 60th St.         Harvard Park
# ..        ...                           ...                  ...
# 58 1992-05-02             11932 Cometa Ave.              Pacoima
# 59 1992-04-29          4365 S. Vermont Ave.       Vermont Square
# 60 1992-04-30  Western Avenue & 92nd Street        Gramercy Park
# 61 1992-04-29         10621 Sepulveda Blvd.        Mission Hills
# 62 1992-04-29        Gage & Western avenues  Chesterfield Square
#
#                          type   longitude   latitude  cross  \
# 0   Officer-involved shooting -118.273976  34.059281      0
# 1            Not riot-related -118.234098  34.062690      1
# 2                    Homicide -118.326816  33.901662      0
# 3   Officer-involved shooting -118.215390  33.903457      1
# 4                       Death -118.304741  33.985667      0
# ..                        ...         ...        ...    ...
# 58                   Homicide -118.412778  34.287098      0
# 59                   Homicide -118.291557  34.005244      0
# 60                   Homicide -118.310004  33.952767      1
# 61                   Homicide -118.467770  34.263184      0
# 62                      Death -118.308952  33.982363      1
#
#                        position                      new_address   old
# 0    (-118.2739756, 34.0592814)                  2009 W. 6th St.  18.0
# 1    (-118.2340982, 34.0626901)        [Main ,  College streets]  47.0
# 2      (-118.326816, 33.901662)              3100 Rosecrans Ave.  45.0
# 3    (-118.2153903, 33.9034569)   [Rosecrans ,  Chester avenues]  30.0
# 4      (-118.304741, 33.985667)                 1600 W. 60th St.  92.0
# ..                          ...                              ...   ...
# 58     (-118.412778, 34.287098)                11932 Cometa Ave.  20.0
# 59  (-118.2915566, 34.00524354)             4365 S. Vermont Ave.  18.0
# 60  (-118.3100043, 33.95276731)  [Western Avenue ,  92nd Street]  33.0
# 61      (-118.46777, 34.263184)            10621 Sepulveda Blvd.  42.0
# 62   (-118.3089517, 33.9823625)        [Gage ,  Western avenues]  29.0
#
# [63 rows x 16 columns]

# %% [markdown]
# <hr>
# <hr>
# Carlos Gregorio Rodríguez
#
# Universidad Complutense de Madrid
#
# <img src="https://static0.makeuseofimages.com/wordpress/wp-content/uploads/2019/11/CC-BY-NC-License.png" alt="cc by nc" width="200"/>
#
# https://creativecommons.org/licenses/by-nc/4.0/
